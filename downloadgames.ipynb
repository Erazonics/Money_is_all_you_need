# %%
import requests
import json
import gzip
import shutil
from io import BytesIO, StringIO
import os

S3_BUCKET_URL = "https://power-rankings-dataset-gprhack.s3.us-west-2.amazonaws.com"
def download_gzip_and_write_to_json(file_name):
    local_file_name = file_name.replace(":", "_")
    # If file already exists locally do not re-download game
    if os.path.isfile(f"{local_file_name}.json"):
        return

    response = requests.get(f"{S3_BUCKET_URL}/{file_name}.json.gz")
    if response.status_code == 200:
        try:
            gzip_bytes = BytesIO(response.content)
            with gzip.GzipFile(fileobj=gzip_bytes, mode="rb") as gzipped_file:
                with open(f"{local_file_name}.json", 'wb') as output_file:
                    shutil.copyfileobj(gzipped_file, output_file)
                print(f"{file_name}.json written")
        except Exception as e:
            print("Error:", e)
    else:
        print(f"Failed to download {file_name}")

def download_gzip_and_shorten_json(file_name):
    local_file_name = file_name.replace(":", "_")
    shortened_file_name = f"{local_file_name}_shortened.json"

    if os.path.isfile(shortened_file_name):
        print(f"{shortened_file_name} already exists.")
        return

    response = requests.get(f"{S3_BUCKET_URL}/{file_name}.json.gz")
    if response.status_code == 200:
        try:
            gzip_bytes = BytesIO(response.content)
            with gzip.GzipFile(fileobj=gzip_bytes, mode="rb") as gzipped_file:
                data = json.load(gzipped_file)

                # Subset and shorten the data
                data = data[-2:]
                extracted_data = []
                for element in data:
                    extracted_element = {
                        'eventTime': element.get('eventTime'),
                        'platformGameId': element.get('platformGameId'),
                        'gameTime': element.get('gameTime'),
                        'participants': [],
                        'teams': []
                    }

                    participants = element.get('participants', [])
                    for participant in participants:
                        extracted_participant = {
                            'participantID': participant.get('participantID'),
                            'totalGold': participant.get('totalGold')
                        }
                        extracted_element['participants'].append(extracted_participant)

                    teams = element.get('teams', [])
                    for team in teams:
                        extracted_team = {
                            'teamID': team.get('teamID'),
                            'totalGold': team.get('totalGold')
                        }
                        extracted_element['teams'].append(extracted_team)

                    if extracted_element['participants'] and extracted_element['teams']:
                        extracted_data.append(extracted_element)

                # Write only the shortened data to disk
                with open(shortened_file_name, 'w') as output_file:
                    json.dump(extracted_data, output_file, indent=2)
                print(f"{shortened_file_name} written")
        except Exception as e:
            print("Error:", e)
    else:
        print(f"Failed to download {file_name}")


def download_esports_files():
    directory = "esports-data"
    if not os.path.exists(directory):
        os.makedirs(directory)

    esports_data_files = ["leagues", "tournaments", "players", "teams", "mapping_data"]
    for file_name in esports_data_files:
        download_gzip_and_write_to_json(f"{directory}/{file_name}")


def download_all_games_from_year(year):
    with open("esports-data/tournaments.json", "r") as json_file:
        tournaments_data = json.load(json_file)
    with open("esports-data/mapping_data.json", "r") as json_file:
        mappings_data = json.load(json_file)

    directory = "games"
    if not os.path.exists(directory):
        os.makedirs(directory)

    mappings = {
        esports_game["esportsGameId"]: esports_game for esports_game in mappings_data
    }

    game_counter = 0

    for tournament in tournaments_data:
        start_date = tournament.get("startDate", "")
        if start_date.startswith(str(year)):
            print(f"Processing {tournament['slug']}")
            for stage in tournament["stages"]:
                for section in stage["sections"]:
                    for match in section["matches"]:
                        for game in match["games"]:
                            if game["state"] == "completed":
                                try:
                                    platform_game_id = mappings[game["id"]]["platformGameId"]
                                except KeyError:
                                    print(f"{game['id']} not found in the mapping table")
                                    continue
                                download_gzip_and_shorten_json(f"{directory}/{platform_game_id}")
                                game_counter += 1

                            if game_counter % 10 == 0:
                                print(f"----- Processed {game_counter} games")


if __name__ == "__main__":
    download_esports_files()
    #download_all_games_from_year(2023)
    #download_all_games_from_year(2022)
    #download_all_games_from_year(2021)
    download_all_games_from_year(2020)
# Out:
# Processing midseason_cup_2020
# games/ESPORTSTMNT03_1392262_shortened.json already exists.
# games/ESPORTSTMNT03_1392233_shortened.json already exists.
# games/ESPORTSTMNT03_1392215_shortened.json already exists.
# games/ESPORTSTMNT03_1392104_shortened.json already exists.
# games/ESPORTSTMNT03_1392251_shortened.json already exists.
# games/ESPORTSTMNT03_1392275_shortened.json already exists.
# games/ESPORTSTMNT03_1382479_shortened.json already exists.
# games/ESPORTSTMNT03_1382462_shortened.json already exists.
# games/ESPORTSTMNT03_1382494_shortened.json already exists.
# games/ESPORTSTMNT03_1382488_shortened.json already exists.
# ----- Processed 10 games
# games/ESPORTSTMNT03_1382425_shortened.json already exists.
# games/ESPORTSTMNT03_1382485_shortened.json already exists.
# games/ESPORTSTMNT03_1382505_shortened.json already exists.
# games/ESPORTSTMNT03_1382513_shortened.json already exists.
# games/ESPORTSTMNT03_1392533_shortened.json already exists.
# games/ESPORTSTMNT03_1392549_shortened.json already exists.
# games/ESPORTSTMNT03_1392556_shortened.json already exists.
# games/ESPORTSTMNT03_1392557_shortened.json already exists.
# games/ESPORTSTMNT03_1392568_shortened.json already exists.
# games/ESPORTSTMNT03_1392576_shortened.json already exists.
# ----- Processed 20 games
# games/ESPORTSTMNT03_1392579_shortened.json already exists.
# games/ESPORTSTMNT03_1392712_shortened.json already exists.
# games/ESPORTSTMNT03_1392714_shortened.json already exists.
# games/ESPORTSTMNT03_1392715_shortened.json already exists.
# games/ESPORTSTMNT03_1392719_shortened.json already exists.
# Processing lcs_academy_summer_2020
# games/ESPORTSTMNT03_1411417_shortened.json already exists.
# games/ESPORTSTMNT02_1394183_shortened.json already exists.
# games/ESPORTSTMNT01_1403502_shortened.json already exists.
# games/ESPORTSTMNT02_1381775_shortened.json already exists.
# games/ESPORTSTMNT03_1401392_shortened.json already exists.
# ----- Processed 30 games
# games/ESPORTSTMNT02_1384656_shortened.json already exists.
# games/ESPORTSTMNT01_1403735_shortened.json already exists.
# games/ESPORTSTMNT03_1413700_shortened.json already exists.
# games/ESPORTSTMNT02_1381556_shortened.json already exists.
# games/ESPORTSTMNT03_1413711_shortened.json already exists.
# games/ESPORTSTMNT01_1403768_shortened.json already exists.
# games/ESPORTSTMNT03_1401377_shortened.json already exists.
# games/ESPORTSTMNT01_1403464_shortened.json already exists.
# games/ESPORTSTMNT02_1381599_shortened.json already exists.
# games/ESPORTSTMNT02_1381823_shortened.json already exists.
# ----- Processed 40 games
# games/ESPORTSTMNT02_1394208_shortened.json already exists.
# games/ESPORTSTMNT02_1384652_shortened.json already exists.
# games/ESPORTSTMNT02_1391665_shortened.json already exists.
# games/ESPORTSTMNT02_1384620_shortened.json already exists.
# games/ESPORTSTMNT02_1381603_shortened.json already exists.
# games/ESPORTSTMNT01_1413786_shortened.json already exists.
# games/ESPORTSTMNT03_1401345_shortened.json already exists.
# games/ESPORTSTMNT01_1403532_shortened.json already exists.
# games/ESPORTSTMNT03_1411452_shortened.json already exists.
# games/ESPORTSTMNT03_1413662_shortened.json already exists.
# ----- Processed 50 games
# games/ESPORTSTMNT02_1394234_shortened.json already exists.
# games/ESPORTSTMNT03_1401572_shortened.json already exists.
# games/ESPORTSTMNT02_1384619_shortened.json already exists.
# games/ESPORTSTMNT02_1381573_shortened.json already exists.
# games/ESPORTSTMNT03_1401373_shortened.json already exists.
# games/ESPORTSTMNT03_1401600_shortened.json already exists.
# games/ESPORTSTMNT01_1403480_shortened.json already exists.
# games/ESPORTSTMNT02_1381589_shortened.json already exists.
# games/ESPORTSTMNT01_1403767_shortened.json already exists.
# games/ESPORTSTMNT02_1384309_shortened.json already exists.
# ----- Processed 60 games
# games/ESPORTSTMNT02_1381824_shortened.json already exists.
# games/ESPORTSTMNT03_1413677_shortened.json already exists.
# games/ESPORTSTMNT02_1384654_shortened.json already exists.
# games/ESPORTSTMNT01_1413742_shortened.json already exists.
# games/ESPORTSTMNT02_1384341_shortened.json already exists.
# games/ESPORTSTMNT03_1401362_shortened.json already exists.
# games/ESPORTSTMNT03_1413694_shortened.json already exists.
# games/ESPORTSTMNT03_1401602_shortened.json already exists.
# games/ESPORTSTMNT01_1403432_shortened.json already exists.
# games/ESPORTSTMNT02_1381776_shortened.json already exists.
# ----- Processed 70 games
# games/ESPORTSTMNT01_1434263_shortened.json already exists.
# games/ESPORTSTMNT01_1434574_shortened.json already exists.
# games/ESPORTSTMNT03_1404247_shortened.json already exists.
# games/ESPORTSTMNT01_1431397_shortened.json already exists.
# games/ESPORTSTMNT02_1401313_shortened.json already exists.
# games/ESPORTSTMNT02_1411426_shortened.json already exists.
# games/ESPORTSTMNT02_1412971_shortened.json already exists.
# games/ESPORTSTMNT02_1403511_shortened.json already exists.
# games/ESPORTSTMNT01_1431669_shortened.json already exists.
# games/ESPORTSTMNT02_1401482_shortened.json already exists.
# ----- Processed 80 games
# games/ESPORTSTMNT01_1431635_shortened.json already exists.
# games/ESPORTSTMNT02_1403051_shortened.json already exists.
# games/ESPORTSTMNT02_1403474_shortened.json already exists.
# games/ESPORTSTMNT03_1413982_shortened.json already exists.
# games/ESPORTSTMNT02_1401302_shortened.json already exists.
# games/ESPORTSTMNT01_1431440_shortened.json already exists.
# games/ESPORTSTMNT01_1434546_shortened.json already exists.
# games/ESPORTSTMNT01_1431443_shortened.json already exists.
# games/ESPORTSTMNT02_1401270_shortened.json already exists.
# games/ESPORTSTMNT03_1413956_shortened.json already exists.
# ----- Processed 90 games
# games/ESPORTSTMNT01_1434277_shortened.json already exists.
# games/ESPORTSTMNT02_1413388_shortened.json already exists.
# games/ESPORTSTMNT01_1431668_shortened.json already exists.
# games/ESPORTSTMNT02_1413008_shortened.json already exists.
# games/ESPORTSTMNT02_1411410_shortened.json already exists.
# games/ESPORTSTMNT02_1403018_shortened.json already exists.
# games/ESPORTSTMNT01_1424413_shortened.json already exists.
# 104174601835007700 not found in the mapping table
# games/ESPORTSTMNT02_1401285_shortened.json already exists.
# games/ESPORTSTMNT02_1413410_shortened.json already exists.
# games/ESPORTSTMNT01_1424446_shortened.json already exists.
# ----- Processed 100 games
# games/ESPORTSTMNT02_1403535_shortened.json already exists.
# games/ESPORTSTMNT01_1431634_shortened.json already exists.
# games/ESPORTSTMNT03_1404226_shortened.json already exists.
# games/ESPORTSTMNT01_1434242_shortened.json already exists.
# games/ESPORTSTMNT01_1431671_shortened.json already exists.
# games/ESPORTSTMNT02_1411425_shortened.json already exists.
# games/ESPORTSTMNT01_1434288_shortened.json already exists.
# games/ESPORTSTMNT01_1431428_shortened.json already exists.
# games/ESPORTSTMNT01_1431418_shortened.json already exists.
# games/ESPORTSTMNT02_1413011_shortened.json already exists.
# ----- Processed 110 games
# games/ESPORTSTMNT02_1401294_shortened.json already exists.
# games/ESPORTSTMNT01_1424448_shortened.json already exists.
# games/ESPORTSTMNT03_1413981_shortened.json already exists.
# games/ESPORTSTMNT02_1401456_shortened.json already exists.
# games/ESPORTSTMNT03_1440879_shortened.json already exists.
# games/ESPORTSTMNT03_1440884_shortened.json already exists.
# games/ESPORTSTMNT03_1440886_shortened.json already exists.
# games/ESPORTSTMNT03_1440716_shortened.json already exists.
# games/ESPORTSTMNT03_1440719_shortened.json already exists.
# games/ESPORTSTMNT03_1430697_shortened.json already exists.
# ----- Processed 120 games
# games/ESPORTSTMNT03_1430700_shortened.json already exists.
# games/ESPORTSTMNT03_1430705_shortened.json already exists.
# games/ESPORTSTMNT03_1441905_shortened.json already exists.
# games/ESPORTSTMNT03_1431949_shortened.json already exists.
# games/ESPORTSTMNT03_1431950_shortened.json already exists.
# games/ESPORTSTMNT03_1441740_shortened.json already exists.
# games/ESPORTSTMNT03_1441746_shortened.json already exists.
# games/ESPORTSTMNT03_1441749_shortened.json already exists.
# games/ESPORTSTMNT03_1432882_shortened.json already exists.
# games/ESPORTSTMNT03_1432889_shortened.json already exists.
# ----- Processed 130 games
# games/ESPORTSTMNT03_1432891_shortened.json already exists.
# games/ESPORTSTMNT03_1432893_shortened.json already exists.
# Processing ljl_spring_2020
# games/ESPORTSTMNT01_1304054_shortened.json already exists.
# games/ESPORTSTMNT02_1294701_shortened.json already exists.
# games/ESPORTSTMNT01_1294233_shortened.json already exists.
# games/ESPORTSTMNT03_1334202_shortened.json already exists.
# games/ESPORTSTMNT03_1331318_shortened.json already exists.
# games/ESPORTSTMNT03_1334852_shortened.json already exists.
# games/ESPORTSTMNT01_1306348_shortened.json already exists.
# games/ESPORTSTMNT02_1294724_shortened.json already exists.
# ----- Processed 140 games
# games/ESPORTSTMNT03_1334438_shortened.json already exists.
# games/ESPORTSTMNT02_1294641_shortened.json already exists.
# games/ESPORTSTMNT01_1306395_shortened.json already exists.
# games/ESPORTSTMNT01_1304020_shortened.json already exists.
# games/ESPORTSTMNT03_1334756_shortened.json already exists.
# games/ESPORTSTMNT03_1334408_shortened.json already exists.
# games/ESPORTSTMNT01_1304217_shortened.json already exists.
# games/ESPORTSTMNT01_1304169_shortened.json already exists.
# games/ESPORTSTMNT03_1331240_shortened.json already exists.
# games/ESPORTSTMNT03_1334768_shortened.json already exists.
# ----- Processed 150 games
# games/ESPORTSTMNT03_1334912_shortened.json already exists.
# games/ESPORTSTMNT02_1294586_shortened.json already exists.
# games/ESPORTSTMNT01_1294260_shortened.json already exists.
# games/ESPORTSTMNT02_1294624_shortened.json already exists.
# games/ESPORTSTMNT03_1331360_shortened.json already exists.
# games/ESPORTSTMNT01_1306271_shortened.json already exists.
# games/ESPORTSTMNT01_1304081_shortened.json already exists.
# games/ESPORTSTMNT02_1294568_shortened.json already exists.
# games/ESPORTSTMNT01_1304132_shortened.json already exists.
# games/ESPORTSTMNT02_1294559_shortened.json already exists.
# ----- Processed 160 games
# games/ESPORTSTMNT03_1331278_shortened.json already exists.
# games/ESPORTSTMNT01_1295541_shortened.json already exists.
# games/ESPORTSTMNT03_1334801_shortened.json already exists.
# games/ESPORTSTMNT02_1294664_shortened.json already exists.
# games/ESPORTSTMNT01_1306413_shortened.json already exists.
# games/ESPORTSTMNT01_1295530_shortened.json already exists.
# games/ESPORTSTMNT03_1334223_shortened.json already exists.
# games/ESPORTSTMNT03_1331262_shortened.json already exists.
# games/ESPORTSTMNT01_1295467_shortened.json already exists.
# games/ESPORTSTMNT01_1295489_shortened.json already exists.
# ----- Processed 170 games
# games/ESPORTSTMNT03_1334730_shortened.json already exists.
# games/ESPORTSTMNT03_1334386_shortened.json already exists.
# games/ESPORTSTMNT01_1306371_shortened.json already exists.
# games/ESPORTSTMNT01_1306323_shortened.json already exists.
# games/ESPORTSTMNT03_1334301_shortened.json already exists.
# games/ESPORTSTMNT03_1334720_shortened.json already exists.
# games/ESPORTSTMNT01_1306256_shortened.json already exists.
# games/ESPORTSTMNT01_1295562_shortened.json already exists.
# games/ESPORTSTMNT01_1306283_shortened.json already exists.
# games/ESPORTSTMNT01_1295440_shortened.json already exists.
# ----- Processed 180 games
# games/ESPORTSTMNT03_1331290_shortened.json already exists.
# games/ESPORTSTMNT03_1331336_shortened.json already exists.
# games/ESPORTSTMNT01_1295512_shortened.json already exists.
# games/ESPORTSTMNT03_1334872_shortened.json already exists.
# games/ESPORTSTMNT03_1331375_shortened.json already exists.
# games/ESPORTSTMNT03_1334347_shortened.json already exists.
# games/ESPORTSTMNT03_1334258_shortened.json already exists.
# games/ESPORTSTMNT01_1295588_shortened.json already exists.
# games/ESPORTSTMNT03_1335844_shortened.json already exists.
# games/ESPORTSTMNT01_1325567_shortened.json already exists.
# ----- Processed 190 games
# games/ESPORTSTMNT01_1325582_shortened.json already exists.
# games/ESPORTSTMNT01_1325606_shortened.json already exists.
# games/ESPORTSTMNT01_1325619_shortened.json already exists.
# games/ESPORTSTMNT01_1325639_shortened.json already exists.
# games/ESPORTSTMNT01_1313781_shortened.json already exists.
# 103540398665570569 not found in the mapping table
# 103540398665570570 not found in the mapping table
# games/ESPORTSTMNT01_1313896_shortened.json already exists.
# games/ESPORTSTMNT01_1313913_shortened.json already exists.
# games/ESPORTSTMNT01_1323934_shortened.json already exists.
# games/ESPORTSTMNT01_1323941_shortened.json already exists.
# games/ESPORTSTMNT01_1323953_shortened.json already exists.
# ----- Processed 200 games
# games/ESPORTSTMNT01_1325773_shortened.json already exists.
# games/ESPORTSTMNT01_1325789_shortened.json already exists.
# games/ESPORTSTMNT01_1325816_shortened.json already exists.
# games/ESPORTSTMNT01_1325825_shortened.json already exists.
# games/ESPORTSTMNT01_1325856_shortened.json already exists.
# games/ESPORTSTMNT01_1360856_shortened.json already exists.
# games/ESPORTSTMNT01_1360858_shortened.json already exists.
# games/ESPORTSTMNT01_1360861_shortened.json already exists.
# games/ESPORTSTMNT01_1360862_shortened.json already exists.
# games/ESPORTSTMNT01_1370784_shortened.json already exists.
# ----- Processed 210 games
# games/ESPORTSTMNT01_1370787_shortened.json already exists.
# games/ESPORTSTMNT01_1370788_shortened.json already exists.
# games/ESPORTSTMNT01_1370789_shortened.json already exists.
# Processing opl_2020_split1
# games/ESPORTSTMNT01_1301159_shortened.json already exists.
# games/ESPORTSTMNT02_1283675_shortened.json already exists.
# games/ESPORTSTMNT01_1300964_shortened.json already exists.
# games/ESPORTSTMNT03_1333693_shortened.json already exists.
# games/ESPORTSTMNT01_1304075_shortened.json already exists.
# games/ESPORTSTMNT01_1303478_shortened.json already exists.
# games/ESPORTSTMNT02_1281117_shortened.json already exists.
# ----- Processed 220 games
# games/ESPORTSTMNT01_1303974_shortened.json already exists.
# games/ESPORTSTMNT03_1330974_shortened.json already exists.
# games/ESPORTSTMNT02_1284241_shortened.json already exists.
# games/ESPORTSTMNT02_1281103_shortened.json already exists.
# games/ESPORTSTMNT02_1280872_shortened.json already exists.
# games/ESPORTSTMNT01_1300941_shortened.json already exists.
# games/ESPORTSTMNT03_1330741_shortened.json already exists.
# games/ESPORTSTMNT01_1303533_shortened.json already exists.
# games/ESPORTSTMNT01_1300956_shortened.json already exists.
# games/ESPORTSTMNT02_1281110_shortened.json already exists.
# ----- Processed 230 games
# games/ESPORTSTMNT02_1281100_shortened.json already exists.
# games/ESPORTSTMNT02_1280856_shortened.json already exists.
# games/ESPORTSTMNT02_1280894_shortened.json already exists.
# games/ESPORTSTMNT01_1304032_shortened.json already exists.
# games/ESPORTSTMNT02_1283701_shortened.json already exists.
# games/ESPORTSTMNT01_1301183_shortened.json already exists.
# games/ESPORTSTMNT01_1300935_shortened.json already exists.
# games/ESPORTSTMNT01_1303999_shortened.json already exists.
# 103535402770536748 not found in the mapping table
# games/ESPORTSTMNT01_1303581_shortened.json already exists.
# games/ESPORTSTMNT01_1301128_shortened.json already exists.
# ----- Processed 240 games
# games/ESPORTSTMNT03_1330737_shortened.json already exists.
# games/ESPORTSTMNT02_1330891_shortened.json already exists.
# games/ESPORTSTMNT02_1284276_shortened.json already exists.
# games/ESPORTSTMNT02_1280891_shortened.json already exists.
# games/ESPORTSTMNT03_1334248_shortened.json already exists.
# games/ESPORTSTMNT03_1330989_shortened.json already exists.
# games/ESPORTSTMNT02_1321174_shortened.json already exists.
# games/ESPORTSTMNT02_1321182_shortened.json already exists.
# games/ESPORTSTMNT01_1303509_shortened.json already exists.
# games/ESPORTSTMNT01_1310866_shortened.json already exists.
# ----- Processed 250 games
# games/ESPORTSTMNT02_1321169_shortened.json already exists.
# games/ESPORTSTMNT03_1334221_shortened.json already exists.
# games/ESPORTSTMNT02_1283659_shortened.json already exists.
# games/ESPORTSTMNT01_1301169_shortened.json already exists.
# games/ESPORTSTMNT03_1330987_shortened.json already exists.
# games/ESPORTSTMNT02_1284212_shortened.json already exists.
# games/ESPORTSTMNT01_1310854_shortened.json already exists.
# games/ESPORTSTMNT03_1333677_shortened.json already exists.
# games/ESPORTSTMNT01_1310842_shortened.json already exists.
# games/ESPORTSTMNT03_1334319_shortened.json already exists.
# ----- Processed 260 games
# games/ESPORTSTMNT03_1333703_shortened.json already exists.
# games/ESPORTSTMNT02_1330912_shortened.json already exists.
# games/ESPORTSTMNT03_1330729_shortened.json already exists.
# games/ESPORTSTMNT02_1284202_shortened.json already exists.
# games/ESPORTSTMNT03_1333724_shortened.json already exists.
# games/ESPORTSTMNT01_1310892_shortened.json already exists.
# games/ESPORTSTMNT03_1330966_shortened.json already exists.
# games/ESPORTSTMNT03_1330730_shortened.json already exists.
# games/ESPORTSTMNT01_1313856_shortened.json already exists.
# games/ESPORTSTMNT02_1323478_shortened.json already exists.
# ----- Processed 270 games
# games/ESPORTSTMNT01_1323375_shortened.json already exists.
# games/ESPORTSTMNT02_1322955_shortened.json already exists.
# games/ESPORTSTMNT02_1321192_shortened.json already exists.
# games/ESPORTSTMNT02_1330940_shortened.json already exists.
# games/ESPORTSTMNT02_1323425_shortened.json already exists.
# games/ESPORTSTMNT03_1334281_shortened.json already exists.
# games/ESPORTSTMNT02_1330884_shortened.json already exists.
# games/ESPORTSTMNT02_1323408_shortened.json already exists.
# games/ESPORTSTMNT02_1323452_shortened.json already exists.
# games/ESPORTSTMNT02_1322993_shortened.json already exists.
# ----- Processed 280 games
# games/ESPORTSTMNT01_1323323_shortened.json already exists.
# games/ESPORTSTMNT01_1313839_shortened.json already exists.
# games/ESPORTSTMNT02_1330868_shortened.json already exists.
# games/ESPORTSTMNT01_1323352_shortened.json already exists.
# games/ESPORTSTMNT02_1323085_shortened.json already exists.
# games/ESPORTSTMNT02_1323007_shortened.json already exists.
# games/ESPORTSTMNT02_1323094_shortened.json already exists.
# games/ESPORTSTMNT02_1323051_shortened.json already exists.
# games/ESPORTSTMNT02_1321214_shortened.json already exists.
# games/ESPORTSTMNT02_1323467_shortened.json already exists.
# ----- Processed 290 games
# games/ESPORTSTMNT01_1313804_shortened.json already exists.
# games/ESPORTSTMNT01_1323305_shortened.json already exists.
# games/ESPORTSTMNT02_1321161_shortened.json already exists.
# games/ESPORTSTMNT02_1323497_shortened.json already exists.
# games/ESPORTSTMNT02_1330955_shortened.json already exists.
# games/ESPORTSTMNT01_1313818_shortened.json already exists.
# games/ESPORTSTMNT03_1350663_shortened.json already exists.
# games/ESPORTSTMNT03_1340567_shortened.json already exists.
# games/ESPORTSTMNT03_1340578_shortened.json already exists.
# games/ESPORTSTMNT03_1340588_shortened.json already exists.
# ----- Processed 300 games
# ----- Processed 300 games
# games/ESPORTSTMNT03_1350622_shortened.json already exists.
# games/ESPORTSTMNT03_1350628_shortened.json already exists.
# games/ESPORTSTMNT03_1350635_shortened.json already exists.
# games/ESPORTSTMNT03_1350657_shortened.json already exists.
# games/ESPORTSTMNT03_1340749_shortened.json already exists.
# games/ESPORTSTMNT03_1340757_shortened.json already exists.
# games/ESPORTSTMNT03_1340760_shortened.json already exists.
# games/ESPORTSTMNT03_1340767_shortened.json already exists.
# games/ESPORTSTMNT03_1341941_shortened.json already exists.
# games/ESPORTSTMNT03_1341953_shortened.json already exists.
# ----- Processed 310 games
# games/ESPORTSTMNT03_1341978_shortened.json already exists.
# games/ESPORTSTMNT03_1341982_shortened.json already exists.
# games/ESPORTSTMNT03_1341983_shortened.json already exists.
# games/ESPORTSTMNT03_1342162_shortened.json already exists.
# games/ESPORTSTMNT03_1342172_shortened.json already exists.
# games/ESPORTSTMNT03_1342182_shortened.json already exists.
# games/ESPORTSTMNT03_1342201_shortened.json already exists.
# games/ESPORTSTMNT03_1342214_shortened.json already exists.
# games/ESPORTSTMNT03_1342995_shortened.json already exists.
# games/ESPORTSTMNT03_1343000_shortened.json already exists.
# ----- Processed 320 games
# games/ESPORTSTMNT03_1343002_shortened.json already exists.
# games/ESPORTSTMNT03_1343004_shortened.json already exists.
# Processing cblol_2020_split1
# games/ESPORTSTMNT01_1291703_shortened.json already exists.
# games/ESPORTSTMNT01_1304282_shortened.json already exists.
# games/ESPORTSTMNT03_1331108_shortened.json already exists.
# 103478355179226683 not found in the mapping table
# games/ESPORTSTMNT03_1301276_shortened.json already exists.
# games/ESPORTSTMNT01_1304609_shortened.json already exists.
# games/ESPORTSTMNT01_1301305_shortened.json already exists.
# games/ESPORTSTMNT01_1301262_shortened.json already exists.
# games/ESPORTSTMNT01_1304635_shortened.json already exists.
# ----- Processed 330 games
# games/ESPORTSTMNT03_1331071_shortened.json already exists.
# games/ESPORTSTMNT01_1304324_shortened.json already exists.
# 103478355179226699 not found in the mapping table
# games/ESPORTSTMNT03_1301284_shortened.json already exists.
# games/ESPORTSTMNT03_1301242_shortened.json already exists.
# games/ESPORTSTMNT01_1291682_shortened.json already exists.
# games/ESPORTSTMNT01_1304691_shortened.json already exists.
# games/ESPORTSTMNT03_1301287_shortened.json already exists.
# games/ESPORTSTMNT03_1331130_shortened.json already exists.
# games/ESPORTSTMNT03_1301300_shortened.json already exists.
# games/ESPORTSTMNT01_1291651_shortened.json already exists.
# ----- Processed 340 games
# games/ESPORTSTMNT01_1301270_shortened.json already exists.
# games/ESPORTSTMNT01_1304264_shortened.json already exists.
# games/ESPORTSTMNT01_1301290_shortened.json already exists.
# games/ESPORTSTMNT01_1304302_shortened.json already exists.
# games/ESPORTSTMNT01_1304671_shortened.json already exists.
# games/ESPORTSTMNT03_1331083_shortened.json already exists.
# 103478355179292265 not found in the mapping table
# games/ESPORTSTMNT01_1291737_shortened.json already exists.
# games/ESPORTSTMNT01_1321394_shortened.json already exists.
# games/ESPORTSTMNT01_1321751_shortened.json already exists.
# games/ESPORTSTMNT03_1350888_shortened.json already exists.
# ----- Processed 350 games
# games/ESPORTSTMNT03_1321435_shortened.json already exists.
# games/ESPORTSTMNT03_1324357_shortened.json already exists.
# games/ESPORTSTMNT03_1340678_shortened.json already exists.
# games/ESPORTSTMNT03_1324737_shortened.json already exists.
# games/ESPORTSTMNT03_1324768_shortened.json already exists.
# games/ESPORTSTMNT03_1340672_shortened.json already exists.
# games/ESPORTSTMNT03_1350903_shortened.json already exists.
# games/ESPORTSTMNT01_1321705_shortened.json already exists.
# games/ESPORTSTMNT03_1331477_shortened.json already exists.
# games/ESPORTSTMNT03_1324333_shortened.json already exists.
# ----- Processed 360 games
# games/ESPORTSTMNT03_1331442_shortened.json already exists.
# games/ESPORTSTMNT01_1321427_shortened.json already exists.
# games/ESPORTSTMNT03_1340657_shortened.json already exists.
# games/ESPORTSTMNT03_1324283_shortened.json already exists.
# games/ESPORTSTMNT03_1350856_shortened.json already exists.
# games/ESPORTSTMNT03_1324303_shortened.json already exists.
# games/ESPORTSTMNT01_1321377_shortened.json already exists.
# games/ESPORTSTMNT03_1324707_shortened.json already exists.
# games/ESPORTSTMNT01_1321781_shortened.json already exists.
# games/ESPORTSTMNT03_1324751_shortened.json already exists.
# ----- Processed 370 games
# games/ESPORTSTMNT01_1321729_shortened.json already exists.
# games/ESPORTSTMNT03_1340641_shortened.json already exists.
# games/ESPORTSTMNT03_1350872_shortened.json already exists.
# games/ESPORTSTMNT03_1331462_shortened.json already exists.
# games/ESPORTSTMNT01_1321408_shortened.json already exists.
# games/ESPORTSTMNT03_1352447_shortened.json already exists.
# games/ESPORTSTMNT01_1370161_shortened.json already exists.
# games/ESPORTSTMNT01_1370353_shortened.json already exists.
# games/ESPORTSTMNT03_1341029_shortened.json already exists.
# games/ESPORTSTMNT03_1352098_shortened.json already exists.
# ----- Processed 380 games
# games/ESPORTSTMNT01_1370231_shortened.json already exists.
# games/ESPORTSTMNT03_1342285_shortened.json already exists.
# games/ESPORTSTMNT03_1342295_shortened.json already exists.
# games/ESPORTSTMNT01_1370246_shortened.json already exists.
# games/ESPORTSTMNT01_1370339_shortened.json already exists.
# games/ESPORTSTMNT01_1370134_shortened.json already exists.
# 103478355179292347 not found in the mapping table
# games/ESPORTSTMNT03_1342042_shortened.json already exists.
# games/ESPORTSTMNT03_1340969_shortened.json already exists.
# games/ESPORTSTMNT03_1352457_shortened.json already exists.
# games/ESPORTSTMNT01_1370238_shortened.json already exists.
# ----- Processed 390 games
# games/ESPORTSTMNT03_1352084_shortened.json already exists.
# games/ESPORTSTMNT01_1370327_shortened.json already exists.
# games/ESPORTSTMNT03_1352079_shortened.json already exists.
# games/ESPORTSTMNT03_1352450_shortened.json already exists.
# games/ESPORTSTMNT03_1352257_shortened.json already exists.
# games/ESPORTSTMNT01_1370167_shortened.json already exists.
# games/ESPORTSTMNT03_1342267_shortened.json already exists.
# games/ESPORTSTMNT01_1370145_shortened.json already exists.
# games/ESPORTSTMNT01_1370254_shortened.json already exists.
# games/ESPORTSTMNT01_1370345_shortened.json already exists.
# ----- Processed 400 games
# games/ESPORTSTMNT03_1340995_shortened.json already exists.
# games/ESPORTSTMNT03_1352439_shortened.json already exists.
# games/ESPORTSTMNT01_1380452_shortened.json already exists.
# games/ESPORTSTMNT01_1380453_shortened.json already exists.
# games/ESPORTSTMNT01_1380454_shortened.json already exists.
# 103478355186435828 not found in the mapping table
# 103478355186435829 not found in the mapping table
# games/ESPORTSTMNT01_1360791_shortened.json already exists.
# games/ESPORTSTMNT01_1360796_shortened.json already exists.
# games/ESPORTSTMNT01_1360811_shortened.json already exists.
# games/ESPORTSTMNT01_1370738_shortened.json already exists.
# games/ESPORTSTMNT01_1370748_shortened.json already exists.
# ----- Processed 410 games
# games/ESPORTSTMNT01_1370750_shortened.json already exists.
# games/ESPORTSTMNT01_1390072_shortened.json already exists.
# games/ESPORTSTMNT01_1390080_shortened.json already exists.
# games/ESPORTSTMNT01_1390082_shortened.json already exists.
# Processing tcl_summer_2020
# games/ESPORTSTMNT04_1250247_shortened.json already exists.
# games/ESPORTSTMNT04_1220934_shortened.json already exists.
# games/ESPORTSTMNT06_1300358_shortened.json already exists.
# games/ESPORTSTMNT04_1240489_shortened.json already exists.
# games/ESPORTSTMNT05_1520247_shortened.json already exists.
# games/ESPORTSTMNT04_1220183_shortened.json already exists.
# ----- Processed 420 games
# games/ESPORTSTMNT05_1530146_shortened.json already exists.
# games/ESPORTSTMNT04_1220789_shortened.json already exists.
# games/ESPORTSTMNT04_1230190_shortened.json already exists.
# games/ESPORTSTMNT06_1300338_shortened.json already exists.
# games/ESPORTSTMNT04_1240500_shortened.json already exists.
# games/ESPORTSTMNT04_1240425_shortened.json already exists.
# games/ESPORTSTMNT06_1300410_shortened.json already exists.
# games/ESPORTSTMNT04_1220791_shortened.json already exists.
# games/ESPORTSTMNT04_1230195_shortened.json already exists.
# games/ESPORTSTMNT04_1220920_shortened.json already exists.
# ----- Processed 430 games
# games/ESPORTSTMNT05_1530138_shortened.json already exists.
# games/ESPORTSTMNT06_1300810_shortened.json already exists.
# games/ESPORTSTMNT06_1300419_shortened.json already exists.
# games/ESPORTSTMNT04_1250246_shortened.json already exists.
# games/ESPORTSTMNT05_1510602_shortened.json already exists.
# games/ESPORTSTMNT05_1520223_shortened.json already exists.
# games/ESPORTSTMNT05_1530151_shortened.json already exists.
# games/ESPORTSTMNT04_1220835_shortened.json already exists.
# games/ESPORTSTMNT05_1530143_shortened.json already exists.
# games/ESPORTSTMNT06_1300856_shortened.json already exists.
# ----- Processed 440 games
# games/ESPORTSTMNT04_1250244_shortened.json already exists.
# games/ESPORTSTMNT04_1250198_shortened.json already exists.
# games/ESPORTSTMNT04_1240449_shortened.json already exists.
# games/ESPORTSTMNT06_1300409_shortened.json already exists.
# games/ESPORTSTMNT06_1300821_shortened.json already exists.
# games/ESPORTSTMNT04_1250217_shortened.json already exists.
# games/ESPORTSTMNT04_1220821_shortened.json already exists.
# games/ESPORTSTMNT04_1240224_shortened.json already exists.
# games/ESPORTSTMNT06_1300363_shortened.json already exists.
# games/ESPORTSTMNT05_1530153_shortened.json already exists.
# ----- Processed 450 games
# games/ESPORTSTMNT04_1240486_shortened.json already exists.
# games/ESPORTSTMNT06_1270287_shortened.json already exists.
# games/ESPORTSTMNT04_1220913_shortened.json already exists.
# games/ESPORTSTMNT05_1540150_shortened.json already exists.
# games/ESPORTSTMNT06_1300805_shortened.json already exists.
# games/ESPORTSTMNT04_1240424_shortened.json already exists.
# games/ESPORTSTMNT04_1220214_shortened.json already exists.
# games/ESPORTSTMNT04_1240231_shortened.json already exists.
# games/ESPORTSTMNT05_1510595_shortened.json already exists.
# games/ESPORTSTMNT05_1520182_shortened.json already exists.
# ----- Processed 460 games
# games/ESPORTSTMNT04_1250225_shortened.json already exists.
# games/ESPORTSTMNT05_1540167_shortened.json already exists.
# games/ESPORTSTMNT05_1520598_shortened.json already exists.
# games/ESPORTSTMNT04_1240434_shortened.json already exists.
# games/ESPORTSTMNT06_1300426_shortened.json already exists.
# games/ESPORTSTMNT05_1520651_shortened.json already exists.
# games/ESPORTSTMNT06_1300859_shortened.json already exists.
# games/ESPORTSTMNT06_1300815_shortened.json already exists.
# games/ESPORTSTMNT05_1540177_shortened.json already exists.
# games/ESPORTSTMNT05_1510609_shortened.json already exists.
# ----- Processed 470 games
# games/ESPORTSTMNT05_1510211_shortened.json already exists.
# games/ESPORTSTMNT04_1220209_shortened.json already exists.
# games/ESPORTSTMNT06_1270708_shortened.json already exists.
# games/ESPORTSTMNT06_1270655_shortened.json already exists.
# games/ESPORTSTMNT04_1250201_shortened.json already exists.
# games/ESPORTSTMNT05_1520649_shortened.json already exists.
# games/ESPORTSTMNT04_1230207_shortened.json already exists.
# games/ESPORTSTMNT04_1220206_shortened.json already exists.
# games/ESPORTSTMNT05_1520161_shortened.json already exists.
# games/ESPORTSTMNT04_1250467_shortened.json already exists.
# ----- Processed 480 games
# games/ESPORTSTMNT04_1240418_shortened.json already exists.
# games/ESPORTSTMNT05_1520648_shortened.json already exists.
# games/ESPORTSTMNT06_1300850_shortened.json already exists.
# games/ESPORTSTMNT05_1520653_shortened.json already exists.
# games/ESPORTSTMNT04_1220808_shortened.json already exists.
# games/ESPORTSTMNT05_1520169_shortened.json already exists.
# games/ESPORTSTMNT04_1220888_shortened.json already exists.
# games/ESPORTSTMNT05_1520239_shortened.json already exists.
# games/ESPORTSTMNT04_1220191_shortened.json already exists.
# games/ESPORTSTMNT04_1230203_shortened.json already exists.
# ----- Processed 490 games
# games/ESPORTSTMNT04_1220904_shortened.json already exists.
# games/ESPORTSTMNT06_1300853_shortened.json already exists.
# games/ESPORTSTMNT05_1520153_shortened.json already exists.
# games/ESPORTSTMNT05_1540149_shortened.json already exists.
# games/ESPORTSTMNT05_1520644_shortened.json already exists.
# games/ESPORTSTMNT05_1520595_shortened.json already exists.
# games/ESPORTSTMNT05_1540157_shortened.json already exists.
# games/ESPORTSTMNT04_1250222_shortened.json already exists.
# games/ESPORTSTMNT06_1300369_shortened.json already exists.
# games/ESPORTSTMNT04_1230192_shortened.json already exists.
# ----- Processed 500 games
# games/ESPORTSTMNT05_1520234_shortened.json already exists.
# games/ESPORTSTMNT06_1300416_shortened.json already exists.
# games/ESPORTSTMNT05_1520189_shortened.json already exists.
# games/ESPORTSTMNT04_1240495_shortened.json already exists.
# games/ESPORTSTMNT05_1540184_shortened.json already exists.
# games/ESPORTSTMNT06_1310110_shortened.json already exists.
# games/ESPORTSTMNT06_1310113_shortened.json already exists.
# games/ESPORTSTMNT06_1310115_shortened.json already exists.
# games/ESPORTSTMNT06_1310123_shortened.json already exists.
# games/ESPORTSTMNT06_1310080_shortened.json already exists.
# ----- Processed 510 games
# games/ESPORTSTMNT06_1310089_shortened.json already exists.
# games/ESPORTSTMNT06_1310094_shortened.json already exists.
# games/ESPORTSTMNT06_1320072_shortened.json already exists.
# games/ESPORTSTMNT06_1310389_shortened.json already exists.
# games/ESPORTSTMNT06_1310393_shortened.json already exists.
# games/ESPORTSTMNT06_1310398_shortened.json already exists.
# games/ESPORTSTMNT06_1310400_shortened.json already exists.
# games/ESPORTSTMNT06_1310404_shortened.json already exists.
# games/ESPORTSTMNT06_1320490_shortened.json already exists.
# games/ESPORTSTMNT06_1310415_shortened.json already exists.
# ----- Processed 520 games
# games/ESPORTSTMNT06_1310419_shortened.json already exists.
# games/ESPORTSTMNT06_1320882_shortened.json already exists.
# games/ESPORTSTMNT06_1320889_shortened.json already exists.
# games/ESPORTSTMNT06_1320890_shortened.json already exists.
# games/ESPORTSTMNT06_1320891_shortened.json already exists.
# games/ESPORTSTMNT06_1320893_shortened.json already exists.
# Processing lck_summer_2020
# games/ESPORTSTMNT03_1414469_shortened.json already exists.
# games/ESPORTSTMNT03_1414505_shortened.json already exists.
# games/ESPORTSTMNT02_1383977_shortened.json already exists.
# games/ESPORTSTMNT02_1384018_shortened.json already exists.
# ----- Processed 530 games
# games/ESPORTSTMNT02_1384046_shortened.json already exists.
# games/ESPORTSTMNT02_1385895_shortened.json already exists.
# games/ESPORTSTMNT02_1385913_shortened.json already exists.
# games/ESPORTSTMNT02_1384780_shortened.json already exists.
# games/ESPORTSTMNT02_1384813_shortened.json already exists.
# games/ESPORTSTMNT03_1404039_shortened.json already exists.
# games/ESPORTSTMNT03_1404085_shortened.json already exists.
# games/ESPORTSTMNT02_1386267_shortened.json already exists.
# games/ESPORTSTMNT02_1386295_shortened.json already exists.
# games/ESPORTSTMNT01_1405601_shortened.json already exists.
# ----- Processed 540 games
# games/ESPORTSTMNT01_1405624_shortened.json already exists.
# games/ESPORTSTMNT01_1405637_shortened.json already exists.
# games/ESPORTSTMNT03_1405438_shortened.json already exists.
# games/ESPORTSTMNT03_1405459_shortened.json already exists.
# games/ESPORTSTMNT01_1415338_shortened.json already exists.
# games/ESPORTSTMNT01_1415378_shortened.json already exists.
# games/ESPORTSTMNT01_1415382_shortened.json already exists.
# games/ESPORTSTMNT02_1396074_shortened.json already exists.
# games/ESPORTSTMNT02_1396100_shortened.json already exists.
# games/ESPORTSTMNT03_1413012_shortened.json already exists.
# ----- Processed 550 games
# games/ESPORTSTMNT03_1413045_shortened.json already exists.
# games/ESPORTSTMNT01_1415198_shortened.json already exists.
# games/ESPORTSTMNT01_1415201_shortened.json already exists.
# games/ESPORTSTMNT01_1415210_shortened.json already exists.
# games/ESPORTSTMNT02_1394376_shortened.json already exists.
# games/ESPORTSTMNT02_1394402_shortened.json already exists.
# games/ESPORTSTMNT01_1415502_shortened.json already exists.
# games/ESPORTSTMNT01_1415533_shortened.json already exists.
# games/ESPORTSTMNT01_1415535_shortened.json already exists.
# games/ESPORTSTMNT02_1393318_shortened.json already exists.
# ----- Processed 560 games
# games/ESPORTSTMNT02_1393350_shortened.json already exists.
# games/ESPORTSTMNT02_1395817_shortened.json already exists.
# games/ESPORTSTMNT02_1395842_shortened.json already exists.
# games/ESPORTSTMNT03_1415548_shortened.json already exists.
# games/ESPORTSTMNT03_1415585_shortened.json already exists.
# games/ESPORTSTMNT01_1415320_shortened.json already exists.
# games/ESPORTSTMNT01_1415331_shortened.json already exists.
# games/ESPORTSTMNT01_1405646_shortened.json already exists.
# games/ESPORTSTMNT01_1405650_shortened.json already exists.
# games/ESPORTSTMNT03_1405461_shortened.json already exists.
# ----- Processed 570 games
# games/ESPORTSTMNT03_1405504_shortened.json already exists.
# games/ESPORTSTMNT02_1385861_shortened.json already exists.
# games/ESPORTSTMNT02_1385882_shortened.json already exists.
# games/ESPORTSTMNT02_1384863_shortened.json already exists.
# games/ESPORTSTMNT02_1384878_shortened.json already exists.
# games/ESPORTSTMNT03_1403610_shortened.json already exists.
# games/ESPORTSTMNT03_1403647_shortened.json already exists.
# games/ESPORTSTMNT03_1404383_shortened.json already exists.
# games/ESPORTSTMNT03_1404443_shortened.json already exists.
# games/ESPORTSTMNT03_1404460_shortened.json already exists.
# ----- Processed 580 games
# games/ESPORTSTMNT03_1405661_shortened.json already exists.
# games/ESPORTSTMNT03_1405678_shortened.json already exists.
# games/ESPORTSTMNT03_1405687_shortened.json already exists.
# games/ESPORTSTMNT02_1396105_shortened.json already exists.
# games/ESPORTSTMNT02_1396149_shortened.json already exists.
# games/ESPORTSTMNT02_1396154_shortened.json already exists.
# games/ESPORTSTMNT02_1385182_shortened.json already exists.
# games/ESPORTSTMNT02_1385241_shortened.json already exists.
# games/ESPORTSTMNT03_1404095_shortened.json already exists.
# games/ESPORTSTMNT03_1404129_shortened.json already exists.
# ----- Processed 590 games
# ----- Processed 590 games
# games/ESPORTSTMNT01_1414788_shortened.json already exists.
# games/ESPORTSTMNT01_1414822_shortened.json already exists.
# games/ESPORTSTMNT02_1383936_shortened.json already exists.
# games/ESPORTSTMNT02_1383963_shortened.json already exists.
# games/ESPORTSTMNT02_1383967_shortened.json already exists.
# games/ESPORTSTMNT02_1393266_shortened.json already exists.
# games/ESPORTSTMNT02_1393296_shortened.json already exists.
# games/ESPORTSTMNT02_1393306_shortened.json already exists.
# games/ESPORTSTMNT03_1403547_shortened.json already exists.
# games/ESPORTSTMNT03_1403600_shortened.json already exists.
# ----- Processed 600 games
# ----- Processed 600 games
# games/ESPORTSTMNT02_1386227_shortened.json already exists.
# games/ESPORTSTMNT02_1386265_shortened.json already exists.
# games/ESPORTSTMNT03_1404479_shortened.json already exists.
# games/ESPORTSTMNT03_1404522_shortened.json already exists.
# games/ESPORTSTMNT02_1386473_shortened.json already exists.
# games/ESPORTSTMNT02_1386488_shortened.json already exists.
# games/ESPORTSTMNT03_1414400_shortened.json already exists.
# games/ESPORTSTMNT03_1414435_shortened.json already exists.
# games/ESPORTSTMNT03_1414446_shortened.json already exists.
# games/ESPORTSTMNT01_1415112_shortened.json already exists.
# ----- Processed 610 games
# games/ESPORTSTMNT01_1415168_shortened.json already exists.
# games/ESPORTSTMNT01_1415446_shortened.json already exists.
# games/ESPORTSTMNT01_1415469_shortened.json already exists.
# games/ESPORTSTMNT01_1415487_shortened.json already exists.
# games/ESPORTSTMNT02_1395844_shortened.json already exists.
# games/ESPORTSTMNT02_1395870_shortened.json already exists.
# games/ESPORTSTMNT03_1405626_shortened.json already exists.
# games/ESPORTSTMNT03_1405659_shortened.json already exists.
# games/ESPORTSTMNT02_1394295_shortened.json already exists.
# games/ESPORTSTMNT02_1394346_shortened.json already exists.
# ----- Processed 620 games
# games/ESPORTSTMNT02_1394366_shortened.json already exists.
# games/ESPORTSTMNT01_1414831_shortened.json already exists.
# games/ESPORTSTMNT01_1414864_shortened.json already exists.
# games/ESPORTSTMNT01_1414874_shortened.json already exists.
# games/ESPORTSTMNT02_1386489_shortened.json already exists.
# games/ESPORTSTMNT02_1386500_shortened.json already exists.
# games/ESPORTSTMNT03_1412957_shortened.json already exists.
# games/ESPORTSTMNT03_1412995_shortened.json already exists.
# games/ESPORTSTMNT03_1413000_shortened.json already exists.
# games/ESPORTSTMNT02_1385131_shortened.json already exists.
# ----- Processed 630 games
# games/ESPORTSTMNT02_1385159_shortened.json already exists.
# games/ESPORTSTMNT02_1405416_shortened.json already exists.
# games/ESPORTSTMNT02_1405437_shortened.json already exists.
# games/ESPORTSTMNT02_1403191_shortened.json already exists.
# games/ESPORTSTMNT02_1403220_shortened.json already exists.
# games/ESPORTSTMNT02_1403226_shortened.json already exists.
# games/ESPORTSTMNT02_1414834_shortened.json already exists.
# games/ESPORTSTMNT02_1414857_shortened.json already exists.
# games/ESPORTSTMNT02_1414873_shortened.json already exists.
# games/ESPORTSTMNT01_1426060_shortened.json already exists.
# ----- Processed 640 games
# games/ESPORTSTMNT01_1426081_shortened.json already exists.
# games/ESPORTSTMNT01_1433946_shortened.json already exists.
# games/ESPORTSTMNT01_1433997_shortened.json already exists.
# games/ESPORTSTMNT03_1415705_shortened.json already exists.
# games/ESPORTSTMNT03_1415723_shortened.json already exists.
# games/ESPORTSTMNT02_1404209_shortened.json already exists.
# games/ESPORTSTMNT02_1404245_shortened.json already exists.
# games/ESPORTSTMNT02_1404260_shortened.json already exists.
# games/ESPORTSTMNT03_1441931_shortened.json already exists.
# games/ESPORTSTMNT03_1441978_shortened.json already exists.
# ----- Processed 650 games
# ----- Processed 650 games
# games/ESPORTSTMNT01_1434821_shortened.json already exists.
# games/ESPORTSTMNT01_1434854_shortened.json already exists.
# games/ESPORTSTMNT01_1434878_shortened.json already exists.
# games/ESPORTSTMNT01_1436575_shortened.json already exists.
# games/ESPORTSTMNT01_1436576_shortened.json already exists.
# games/ESPORTSTMNT03_1441795_shortened.json already exists.
# games/ESPORTSTMNT03_1441817_shortened.json already exists.
# games/ESPORTSTMNT03_1415775_shortened.json already exists.
# games/ESPORTSTMNT03_1415780_shortened.json already exists.
# games/ESPORTSTMNT03_1415803_shortened.json already exists.
# ----- Processed 660 games
# games/ESPORTSTMNT03_1442164_shortened.json already exists.
# games/ESPORTSTMNT03_1442181_shortened.json already exists.
# games/ESPORTSTMNT03_1442192_shortened.json already exists.
# games/ESPORTSTMNT01_1434787_shortened.json already exists.
# games/ESPORTSTMNT01_1434797_shortened.json already exists.
# games/ESPORTSTMNT01_1434800_shortened.json already exists.
# games/ESPORTSTMNT02_1413537_shortened.json already exists.
# games/ESPORTSTMNT02_1413560_shortened.json already exists.
# games/ESPORTSTMNT02_1413582_shortened.json already exists.
# games/ESPORTSTMNT01_1425732_shortened.json already exists.
# ----- Processed 670 games
# games/ESPORTSTMNT01_1425770_shortened.json already exists.
# games/ESPORTSTMNT02_1405166_shortened.json already exists.
# games/ESPORTSTMNT02_1405195_shortened.json already exists.
# games/ESPORTSTMNT01_1424245_shortened.json already exists.
# games/ESPORTSTMNT01_1424290_shortened.json already exists.
# games/ESPORTSTMNT02_1403931_shortened.json already exists.
# games/ESPORTSTMNT02_1403961_shortened.json already exists.
# games/ESPORTSTMNT02_1415076_shortened.json already exists.
# games/ESPORTSTMNT02_1415086_shortened.json already exists.
# games/ESPORTSTMNT03_1431586_shortened.json already exists.
# ----- Processed 680 games
# games/ESPORTSTMNT03_1431616_shortened.json already exists.
# games/ESPORTSTMNT03_1442006_shortened.json already exists.
# games/ESPORTSTMNT03_1442035_shortened.json already exists.
# games/ESPORTSTMNT03_1415593_shortened.json already exists.
# games/ESPORTSTMNT03_1415624_shortened.json already exists.
# games/ESPORTSTMNT01_1425772_shortened.json already exists.
# games/ESPORTSTMNT01_1425804_shortened.json already exists.
# games/ESPORTSTMNT01_1435111_shortened.json already exists.
# games/ESPORTSTMNT01_1435174_shortened.json already exists.
# games/ESPORTSTMNT01_1436351_shortened.json already exists.
# ----- Processed 690 games
# games/ESPORTSTMNT01_1436377_shortened.json already exists.
# games/ESPORTSTMNT01_1436394_shortened.json already exists.
# games/ESPORTSTMNT01_1436582_shortened.json already exists.
# games/ESPORTSTMNT01_1436622_shortened.json already exists.
# games/ESPORTSTMNT03_1415661_shortened.json already exists.
# games/ESPORTSTMNT03_1415688_shortened.json already exists.
# games/ESPORTSTMNT02_1415097_shortened.json already exists.
# games/ESPORTSTMNT02_1415116_shortened.json already exists.
# games/ESPORTSTMNT02_1415120_shortened.json already exists.
# games/ESPORTSTMNT02_1403890_shortened.json already exists.
# ----- Processed 700 games
# games/ESPORTSTMNT02_1403916_shortened.json already exists.
# games/ESPORTSTMNT03_1441822_shortened.json already exists.
# games/ESPORTSTMNT03_1441836_shortened.json already exists.
# games/ESPORTSTMNT02_1403233_shortened.json already exists.
# games/ESPORTSTMNT02_1403265_shortened.json already exists.
# games/ESPORTSTMNT02_1405142_shortened.json already exists.
# games/ESPORTSTMNT02_1405151_shortened.json already exists.
# games/ESPORTSTMNT01_1424300_shortened.json already exists.
# games/ESPORTSTMNT01_1424337_shortened.json already exists.
# games/ESPORTSTMNT02_1405442_shortened.json already exists.
# ----- Processed 710 games
# games/ESPORTSTMNT02_1405467_shortened.json already exists.
# games/ESPORTSTMNT02_1405477_shortened.json already exists.
# games/ESPORTSTMNT02_1404158_shortened.json already exists.
# games/ESPORTSTMNT02_1404192_shortened.json already exists.
# games/ESPORTSTMNT01_1435199_shortened.json already exists.
# games/ESPORTSTMNT01_1435224_shortened.json already exists.
# games/ESPORTSTMNT01_1435244_shortened.json already exists.
# games/ESPORTSTMNT02_1413453_shortened.json already exists.
# games/ESPORTSTMNT02_1413490_shortened.json already exists.
# games/ESPORTSTMNT02_1413514_shortened.json already exists.
# ----- Processed 720 games
# games/ESPORTSTMNT03_1415806_shortened.json already exists.
# games/ESPORTSTMNT03_1415826_shortened.json already exists.
# games/ESPORTSTMNT01_1436290_shortened.json already exists.
# games/ESPORTSTMNT01_1436333_shortened.json already exists.
# games/ESPORTSTMNT02_1414883_shortened.json already exists.
# games/ESPORTSTMNT02_1414913_shortened.json already exists.
# games/ESPORTSTMNT03_1442117_shortened.json already exists.
# games/ESPORTSTMNT03_1442138_shortened.json already exists.
# games/ESPORTSTMNT03_1442161_shortened.json already exists.
# games/ESPORTSTMNT03_1431635_shortened.json already exists.
# ----- Processed 730 games
# games/ESPORTSTMNT03_1431664_shortened.json already exists.
# games/ESPORTSTMNT03_1431675_shortened.json already exists.
# games/ESPORTSTMNT01_1433876_shortened.json already exists.
# games/ESPORTSTMNT01_1433919_shortened.json already exists.
# games/ESPORTSTMNT01_1433923_shortened.json already exists.
# games/ESPORTSTMNT01_1426092_shortened.json already exists.
# games/ESPORTSTMNT01_1426113_shortened.json already exists.
# games/ESPORTSTMNT03_1432486_shortened.json already exists.
# games/ESPORTSTMNT03_1432507_shortened.json already exists.
# games/ESPORTSTMNT03_1432517_shortened.json already exists.
# ----- Processed 740 games
# games/ESPORTSTMNT03_1442655_shortened.json already exists.
# games/ESPORTSTMNT03_1442708_shortened.json already exists.
# games/ESPORTSTMNT03_1442724_shortened.json already exists.
# games/ESPORTSTMNT03_1433021_shortened.json already exists.
# games/ESPORTSTMNT03_1433058_shortened.json already exists.
# games/ESPORTSTMNT03_1433070_shortened.json already exists.
# 104174613353783764 not found in the mapping table
# 104174613353783765 not found in the mapping table
# games/ESPORTSTMNT03_1443415_shortened.json already exists.
# games/ESPORTSTMNT03_1443471_shortened.json already exists.
# games/ESPORTSTMNT03_1443489_shortened.json already exists.
# games/ESPORTSTMNT03_1433759_shortened.json already exists.
# ----- Processed 750 games
# games/ESPORTSTMNT03_1433779_shortened.json already exists.
# games/ESPORTSTMNT03_1433782_shortened.json already exists.
# games/ESPORTSTMNT03_1443670_shortened.json already exists.
# games/ESPORTSTMNT03_1443697_shortened.json already exists.
# games/ESPORTSTMNT03_1443700_shortened.json already exists.
# games/ESPORTSTMNT03_1443702_shortened.json already exists.
# games/ESPORTSTMNT03_1443715_shortened.json already exists.
# games/ESPORTSTMNT03_1443731_shortened.json already exists.
# games/ESPORTSTMNT03_1443737_shortened.json already exists.
# Processing lec_spring_2020
# games/ESPORTSTMNT05_1410760_shortened.json already exists.
# ----- Processed 760 games
# games/ESPORTSTMNT05_1410131_shortened.json already exists.
# games/ESPORTSTMNT05_1400210_shortened.json already exists.
# games/ESPORTSTMNT04_1120607_shortened.json already exists.
# games/ESPORTSTMNT04_1130210_shortened.json already exists.
# ...
# games/ESPORTSTMNT02_1270866_shortened.json written
# games/ESPORTSTMNT01_1291812_shortened.json written
# games/ESPORTSTMNT02_1294500_shortened.json written
# games/ESPORTSTMNT01_1295402_shortened.json written
# games/ESPORTSTMNT02_1281254_shortened.json written
# games/ESPORTSTMNT02_1270607_shortened.json written
# games/ESPORTSTMNT01_1291835_shortened.json written
# games/ESPORTSTMNT01_1304700_shortened.json written
# games/ESPORTSTMNT02_1270576_shortened.json written
# ----- Processed 2310 games
# games/ESPORTSTMNT01_1291426_shortened.json written
# games/ESPORTSTMNT01_1292345_shortened.json written
# games/ESPORTSTMNT02_1281506_shortened.json written
# games/ESPORTSTMNT02_1281322_shortened.json written
# games/ESPORTSTMNT02_1281549_shortened.json written
# games/ESPORTSTMNT02_1270874_shortened.json written
# games/ESPORTSTMNT02_1281307_shortened.json written
# games/ESPORTSTMNT01_1291406_shortened.json written
# games/ESPORTSTMNT01_1291748_shortened.json written
# games/ESPORTSTMNT01_1295383_shortened.json written
# ----- Processed 2320 games
# games/ESPORTSTMNT01_1304374_shortened.json written
# games/ESPORTSTMNT02_1294512_shortened.json written
# games/ESPORTSTMNT02_1291972_shortened.json written
# games/ESPORTSTMNT02_1270592_shortened.json written
# games/ESPORTSTMNT02_1295398_shortened.json written
# games/ESPORTSTMNT02_1331415_shortened.json written
# games/ESPORTSTMNT02_1321635_shortened.json written
# games/ESPORTSTMNT01_1324492_shortened.json written
# games/ESPORTSTMNT06_1170778_shortened.json written
# games/ESPORTSTMNT01_1324153_shortened.json written
# ----- Processed 2330 games
# games/ESPORTSTMNT03_1334696_shortened.json written
# games/ESPORTSTMNT03_1331601_shortened.json written
# games/ESPORTSTMNT03_1331220_shortened.json written
# games/ESPORTSTMNT03_1334618_shortened.json written
# games/ESPORTSTMNT01_1324468_shortened.json written
# games/ESPORTSTMNT02_1331597_shortened.json written
# games/ESPORTSTMNT03_1331568_shortened.json written
# games/ESPORTSTMNT03_1331180_shortened.json written
# games/ESPORTSTMNT06_1170753_shortened.json written
# games/ESPORTSTMNT01_1324117_shortened.json written
# ----- Processed 2340 games
# games/ESPORTSTMNT02_1321340_shortened.json written
# games/ESPORTSTMNT02_1294908_shortened.json written
# games/ESPORTSTMNT03_1332066_shortened.json written
# games/ESPORTSTMNT01_1324430_shortened.json written
# games/ESPORTSTMNT02_1321647_shortened.json written
# games/ESPORTSTMNT03_1331160_shortened.json written
# games/ESPORTSTMNT06_1170847_shortened.json written
# games/ESPORTSTMNT01_1314115_shortened.json written
# games/ESPORTSTMNT02_1321429_shortened.json written
# games/ESPORTSTMNT03_1332030_shortened.json written
# ----- Processed 2350 games
# games/ESPORTSTMNT06_1170837_shortened.json written
# games/ESPORTSTMNT01_1324190_shortened.json written
# games/ESPORTSTMNT03_1331198_shortened.json written
# games/ESPORTSTMNT06_1170738_shortened.json written
# games/ESPORTSTMNT01_1314148_shortened.json written
# games/ESPORTSTMNT02_1295365_shortened.json written
# games/ESPORTSTMNT03_1331545_shortened.json written
# games/ESPORTSTMNT06_1170767_shortened.json written
# games/ESPORTSTMNT03_1334645_shortened.json written
# games/ESPORTSTMNT03_1334671_shortened.json written
# ----- Processed 2360 games
# games/ESPORTSTMNT02_1294954_shortened.json written
# games/ESPORTSTMNT02_1331470_shortened.json written
# games/ESPORTSTMNT02_1321674_shortened.json written
# games/ESPORTSTMNT02_1321388_shortened.json written
# games/ESPORTSTMNT01_1324422_shortened.json written
# games/ESPORTSTMNT03_1331501_shortened.json written
# games/ESPORTSTMNT02_1331571_shortened.json written
# games/ESPORTSTMNT01_1324479_shortened.json written
# games/ESPORTSTMNT02_1294934_shortened.json written
# games/ESPORTSTMNT02_1331769_shortened.json written
# ----- Processed 2370 games
# games/ESPORTSTMNT02_1321851_shortened.json written
# games/ESPORTSTMNT02_1331801_shortened.json written
# games/ESPORTSTMNT02_1321871_shortened.json written
# games/ESPORTSTMNT05_1430458_shortened.json written
# games/ESPORTSTMNT05_1440492_shortened.json written
# games/ESPORTSTMNT05_1440493_shortened.json written
# games/ESPORTSTMNT02_1333569_shortened.json written
# games/ESPORTSTMNT02_1333580_shortened.json written
# games/ESPORTSTMNT02_1333591_shortened.json written
# games/ESPORTSTMNT02_1333603_shortened.json written
# ----- Processed 2380 games
# ----- Processed 2380 games
# games/ESPORTSTMNT05_1430690_shortened.json written
# games/ESPORTSTMNT05_1430694_shortened.json written
# games/ESPORTSTMNT05_1430695_shortened.json written
# games/ESPORTSTMNT05_1430696_shortened.json written
# games/ESPORTSTMNT05_1430490_shortened.json written
# games/ESPORTSTMNT05_1430518_shortened.json written
# games/ESPORTSTMNT05_1430523_shortened.json written
# games/ESPORTSTMNT05_1440594_shortened.json written
# games/ESPORTSTMNT05_1440595_shortened.json written
# games/ESPORTSTMNT05_1440596_shortened.json written
# ----- Processed 2390 games
# games/ESPORTSTMNT05_1440597_shortened.json written
# games/ESPORTSTMNT05_1440598_shortened.json written
# games/ESPORTSTMNT05_1440699_shortened.json written
# games/ESPORTSTMNT05_1440707_shortened.json written
# games/ESPORTSTMNT05_1440708_shortened.json written
# games/ESPORTSTMNT05_1440709_shortened.json written
# games/ESPORTSTMNT05_1430715_shortened.json written
# games/ESPORTSTMNT05_1440738_shortened.json written
# games/ESPORTSTMNT05_1440743_shortened.json written
# games/ESPORTSTMNT05_1440744_shortened.json written
# ----- Processed 2400 games
# games/ESPORTSTMNT05_1440745_shortened.json written
# games/ESPORTSTMNT05_1430798_shortened.json written
# games/ESPORTSTMNT05_1430804_shortened.json written
# games/ESPORTSTMNT05_1430805_shortened.json written
# Processing tal_summer_2020
# games/ESPORTSTMNT04_1230698_shortened.json written
# games/ESPORTSTMNT04_1240169_shortened.json written
# games/ESPORTSTMNT05_1540099_shortened.json written
# games/ESPORTSTMNT05_1520505_shortened.json written
# games/ESPORTSTMNT05_1540037_shortened.json written
# games/ESPORTSTMNT05_1510088_shortened.json written
# ----- Processed 2410 games
# games/ESPORTSTMNT06_1300678_shortened.json written
# games/ESPORTSTMNT04_1220596_shortened.json written
# games/ESPORTSTMNT04_1230325_shortened.json written
# games/ESPORTSTMNT04_1220593_shortened.json written
# games/ESPORTSTMNT05_1540057_shortened.json written
# games/ESPORTSTMNT05_1510113_shortened.json written
# games/ESPORTSTMNT05_1520487_shortened.json written
# games/ESPORTSTMNT04_1240153_shortened.json written
# games/ESPORTSTMNT04_1230341_shortened.json written
# games/ESPORTSTMNT04_1230431_shortened.json written
# ----- Processed 2420 games
# games/ESPORTSTMNT05_1540088_shortened.json written
# games/ESPORTSTMNT04_1250136_shortened.json written
# games/ESPORTSTMNT06_1270216_shortened.json written
# games/ESPORTSTMNT04_1230420_shortened.json written
# games/ESPORTSTMNT05_1520498_shortened.json written
# games/ESPORTSTMNT05_1510549_shortened.json written
# games/ESPORTSTMNT06_1300303_shortened.json written
# games/ESPORTSTMNT05_1510117_shortened.json written
# games/ESPORTSTMNT06_1300687_shortened.json written
# games/ESPORTSTMNT04_1220616_shortened.json written
# ----- Processed 2430 games
# games/ESPORTSTMNT04_1230301_shortened.json written
# games/ESPORTSTMNT04_1250344_shortened.json written
# games/ESPORTSTMNT05_1520504_shortened.json written
# games/ESPORTSTMNT04_1240164_shortened.json written
# games/ESPORTSTMNT04_1230279_shortened.json written
# games/ESPORTSTMNT05_1540051_shortened.json written
# games/ESPORTSTMNT04_1240125_shortened.json written
# games/ESPORTSTMNT05_1520073_shortened.json written
# games/ESPORTSTMNT04_1220603_shortened.json written
# games/ESPORTSTMNT06_1300249_shortened.json written
# ----- Processed 2440 games
# games/ESPORTSTMNT05_1520083_shortened.json written
# games/ESPORTSTMNT04_1250347_shortened.json written
# games/ESPORTSTMNT04_1250129_shortened.json written
# games/ESPORTSTMNT04_1220607_shortened.json written
# games/ESPORTSTMNT04_1250124_shortened.json written
# games/ESPORTSTMNT06_1300694_shortened.json written
# games/ESPORTSTMNT06_1300254_shortened.json written
# games/ESPORTSTMNT05_1520490_shortened.json written
# games/ESPORTSTMNT05_1540064_shortened.json written
# games/ESPORTSTMNT04_1250118_shortened.json written
# ----- Processed 2450 games
# games/ESPORTSTMNT05_1520078_shortened.json written
# games/ESPORTSTMNT06_1270211_shortened.json written
# games/ESPORTSTMNT04_1240403_shortened.json written
# games/ESPORTSTMNT05_1510546_shortened.json written
# games/ESPORTSTMNT04_1250352_shortened.json written
# games/ESPORTSTMNT04_1230436_shortened.json written
# games/ESPORTSTMNT06_1300745_shortened.json written
# games/ESPORTSTMNT06_1270251_shortened.json written
# games/ESPORTSTMNT06_1300755_shortened.json written
# games/ESPORTSTMNT05_1510544_shortened.json written
# ----- Processed 2460 games
# games/ESPORTSTMNT04_1250362_shortened.json written
# games/ESPORTSTMNT04_1240399_shortened.json written
# games/ESPORTSTMNT05_1520057_shortened.json written
# games/ESPORTSTMNT06_1270255_shortened.json written
# games/ESPORTSTMNT06_1300683_shortened.json written
# games/ESPORTSTMNT06_1270203_shortened.json written
# games/ESPORTSTMNT04_1230703_shortened.json written
# games/ESPORTSTMNT05_1540092_shortened.json written
# games/ESPORTSTMNT06_1300688_shortened.json written
# games/ESPORTSTMNT04_1240393_shortened.json written
# ----- Processed 2470 games
# games/ESPORTSTMNT05_1540054_shortened.json written
# games/ESPORTSTMNT04_1230268_shortened.json written
# games/ESPORTSTMNT04_1250358_shortened.json written
# games/ESPORTSTMNT04_1230415_shortened.json written
# games/ESPORTSTMNT06_1300750_shortened.json written
# games/ESPORTSTMNT06_1270261_shortened.json written
# games/ESPORTSTMNT05_1510096_shortened.json written
# games/ESPORTSTMNT04_1240378_shortened.json written
# games/ESPORTSTMNT05_1520065_shortened.json written
# games/ESPORTSTMNT06_1300278_shortened.json written
# ----- Processed 2480 games
# games/ESPORTSTMNT05_1510551_shortened.json written
# 104253013262865980 not found in the mapping table
# games/ESPORTSTMNT04_1240159_shortened.json written
# games/ESPORTSTMNT06_1300753_shortened.json written
# games/ESPORTSTMNT05_1540076_shortened.json written
# games/ESPORTSTMNT04_1240177_shortened.json written
# games/ESPORTSTMNT05_1510101_shortened.json written
# games/ESPORTSTMNT04_1230690_shortened.json written
# games/ESPORTSTMNT06_1300752_shortened.json written
# games/ESPORTSTMNT04_1230686_shortened.json written
# games/ESPORTSTMNT04_1230448_shortened.json written
# ----- Processed 2490 games
# games/ESPORTSTMNT05_1540080_shortened.json written
# games/ESPORTSTMNT04_1240382_shortened.json written
# games/ESPORTSTMNT05_1510540_shortened.json written
# games/ESPORTSTMNT05_1540111_shortened.json written
# games/ESPORTSTMNT05_1540396_shortened.json written
# games/ESPORTSTMNT05_1540399_shortened.json written
# games/ESPORTSTMNT05_1540400_shortened.json written
# games/ESPORTSTMNT05_1540251_shortened.json written
# games/ESPORTSTMNT05_1530262_shortened.json written
# games/ESPORTSTMNT05_1530264_shortened.json written
# ----- Processed 2500 games
# games/ESPORTSTMNT05_1530265_shortened.json written
# games/ESPORTSTMNT05_1540433_shortened.json written
# games/ESPORTSTMNT05_1540436_shortened.json written
# games/ESPORTSTMNT05_1540442_shortened.json written
# games/ESPORTSTMNT05_1540447_shortened.json written
# Processing ase_2020
# games/ESPORTSTMNT06_1490073_shortened.json written
# games/ESPORTSTMNT03_1641027_shortened.json written
# games/ESPORTSTMNT03_1641007_shortened.json written
# games/ESPORTSTMNT03_1631061_shortened.json written
# games/ESPORTSTMNT03_1641138_shortened.json written
# ----- Processed 2510 games
# games/ESPORTSTMNT03_1641158_shortened.json written
# games/ESPORTSTMNT03_1631193_shortened.json written
# games/ESPORTSTMNT03_1631206_shortened.json written
# games/ESPORTSTMNT03_1641086_shortened.json written
# games/ESPORTSTMNT03_1631118_shortened.json written
# games/ESPORTSTMNT03_1631137_shortened.json written
# games/ESPORTSTMNT03_1631134_shortened.json written
# games/ESPORTSTMNT03_1631486_shortened.json written
# games/ESPORTSTMNT03_1631500_shortened.json written
# games/ESPORTSTMNT03_1631516_shortened.json written
# ----- Processed 2520 games
# games/ESPORTSTMNT03_1631520_shortened.json written
# Processing lla-closing-2020
# 104237136858336658 not found in the mapping table
# 104237136858336660 not found in the mapping table
# 104237136858336662 not found in the mapping table
# 104237136858336664 not found in the mapping table
# 104237136858336666 not found in the mapping table
# 104237136858336668 not found in the mapping table
# 104237136858336670 not found in the mapping table
# 104237136858336672 not found in the mapping table
# 104237136858336674 not found in the mapping table
# 104237136858336676 not found in the mapping table
# 104237136858336678 not found in the mapping table
# 104237136858336680 not found in the mapping table
# 104237136858336682 not found in the mapping table
# 104237136858336684 not found in the mapping table
# 104237136858336686 not found in the mapping table
# 104237136858336688 not found in the mapping table
# 104237136858336690 not found in the mapping table
# 104237136858336692 not found in the mapping table
# 104237136858336694 not found in the mapping table
# 104237136858336696 not found in the mapping table
# 104237136858336698 not found in the mapping table
# 104237136858336700 not found in the mapping table
# 104237136858336702 not found in the mapping table
# 104237136858336704 not found in the mapping table
# 104237136858336706 not found in the mapping table
# 104237136858336708 not found in the mapping table
# 104237136858336710 not found in the mapping table
# 104237136858336712 not found in the mapping table
# 104237136858336714 not found in the mapping table
# 104237136858336716 not found in the mapping table
# 104237136858336718 not found in the mapping table
# 104237136858336720 not found in the mapping table
# 104237136858336722 not found in the mapping table
# 104237136858336724 not found in the mapping table
# 104237136858336726 not found in the mapping table
# 104237136858336728 not found in the mapping table
# 104237136858336730 not found in the mapping table
# 104237136858336732 not found in the mapping table
# 104237136858336734 not found in the mapping table
# 104237136858336736 not found in the mapping table
# 104237136858336738 not found in the mapping table
# 104237136858336740 not found in the mapping table
# 104237136858336742 not found in the mapping table
# 104237136858336744 not found in the mapping table
# 104237136858336746 not found in the mapping table
# 104237136858336748 not found in the mapping table
# 104237136858336750 not found in the mapping table
# 104237136858336752 not found in the mapping table
# 104237136858336754 not found in the mapping table
# 104237136858336756 not found in the mapping table
# 104237136858336758 not found in the mapping table
# 104237136858336760 not found in the mapping table
# 104237136858336762 not found in the mapping table
# 104237136858336764 not found in the mapping table
# 104237136858336766 not found in the mapping table
# 104237136858336768 not found in the mapping table
# 104237136864300546 not found in the mapping table
# 104237136864300548 not found in the mapping table
# 104237136864300550 not found in the mapping table
# 104237136864300552 not found in the mapping table
# 104237136864300554 not found in the mapping table
# 104237136864300556 not found in the mapping table
# 104237136864300558 not found in the mapping table
# 104237136864300560 not found in the mapping table
# 104237136864300562 not found in the mapping table
# 104237136864300564 not found in the mapping table
# 104237136865807895 not found in the mapping table
# 104237136865807896 not found in the mapping table
# 104237136865807897 not found in the mapping table
# 104237136865807898 not found in the mapping table
# 104237136865807899 not found in the mapping table
# 104237136865807901 not found in the mapping table
# 104237136865807902 not found in the mapping table
# 104237136865807903 not found in the mapping table
# games/ESPORTSTMNT03_1432131_shortened.json written
# 104237136865807907 not found in the mapping table
# 104237136865807908 not found in the mapping table
# 104237136865807909 not found in the mapping table
# 104237136865807910 not found in the mapping table
# 104237136865807911 not found in the mapping table

# %%
# !zip -r games.zip games
# Out:
# updating: games/ (stored 0%)
# updating: games/ESPORTSTMNT01_2697288_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2450129_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2471889_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3218641_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2450840_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3085550_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3215095_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2551444_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2821251_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2673966_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2574986_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2914630_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2707442_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3170851_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3094622_shortened.json (deflated 75%)
# updating: games/LPL_A_337045_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3194887_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3193440_shortened.json (deflated 75%)
# updating: games/LPL_A_343444_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2693886_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2140079_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2951399_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2767276_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2540910_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2782430_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3197398_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2666120_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2210385_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3144139_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2905082_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2600068_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2906054_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3098578_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2683130_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2971006_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3192630_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3142276_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3177321_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3314636_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3089112_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3316094_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3212665_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3333185_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2573620_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3144372_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2661035_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2637213_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2673250_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2774489_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3090183_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2578469_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3221095_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3217831_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2810806_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3342095_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3332618_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT03_2794729_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3417254_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2818639_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3311011_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT01_3395123_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3124374_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3367502_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3123645_shortened.json (deflated 75%)
# updating: games/LPL_A_331384_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT01_3301928_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3092442_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2532090_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3102279_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2952686_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2750215_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2630904_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2500194_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3415472_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3218326_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2943220_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2789374_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3093889_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3045472_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2896294_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2430761_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2568586_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3402287_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3092604_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2789933_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3197400_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2796826_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3134337_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2569639_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3162355_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3300956_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2460324_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2783398_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2815885_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2532171_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3186869_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2744612_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2884954_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3338036_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3052843_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3090903_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3060382_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2901284_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2290305_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3217192_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3182352_shortened.json (deflated 75%)
# updating: games/LPL_B_323139_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT01_3417173_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3241417_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2541799_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2810167_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2817829_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2564430_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3127560_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3167879_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3216184_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2636995_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3372650_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3190813_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3313862_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2687367_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2815768_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT03_3131628_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2735423_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2780214_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2966012_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2573026_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3111864_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3324554_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2686476_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3331844_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2823231_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3221854_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2670224_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3218128_shortened.json (deflated 75%)
# updating: games/LPL_B_327216_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2220548_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3331763_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2822421_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2770415_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2800565_shortened.json (deflated 75%)
# updating: games/LPL_A_330376_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT04_2686001_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3083415_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2768284_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3322691_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3191226_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3151708_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2799931_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3083253_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3344237_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2565402_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3404825_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3197839_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2220386_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2531244_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2789654_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2669466_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2713164_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2451137_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3164335_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2884198_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3333149_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2663886_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3140458_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3303746_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2531721_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2573978_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3208561_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3368985_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3080905_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3060661_shortened.json (deflated 75%)
# updating: games/LPL_B_326640_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2200388_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3310874_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2411537_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3328190_shortened.json (deflated 75%)
# updating: games/LPL_A_335146_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT01_2984946_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2657884_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3327461_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2460441_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2662360_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2672402_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3091830_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2750332_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3090307_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2990549_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2543541_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3191622_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3213439_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2451371_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3240562_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2541603_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2913703_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3170256_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3131781_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3372092_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3183997_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3167959_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3335723_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2930073_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2903264_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2694099_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2952965_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2893189_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2557859_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3303665_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2673689_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2973776_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2789653_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3330557_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2980586_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3408461_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2793397_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2520472_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3295610_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3221296_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2790886_shortened.json (deflated 75%)
# updating: games/LPL_A_329701_shortened.json (deflated 76%)
# updating: games/LPL_A_342193_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2110478_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2696199_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2819647_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3171544_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2750170_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2580313_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3325049_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2543208_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3122376_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3213817_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3167699_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3120918_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2531145_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3218341_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2768347_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3403673_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3118632_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3086700_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2210486_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2578012_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3371741_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2673984_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3130557_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2740913_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3060409_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2684838_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2431274_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2799832_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2990765_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2794828_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2951104_shortened.json (deflated 75%)
# updating: games/LPL_A_343543_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT02_3219631_shortened.json (deflated 75%)
# updating: games/LPL_A_335524_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT02_3215356_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3116931_shortened.json (deflated 75%)
# updating: games/LPL_B_328800_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3221593_shortened.json (deflated 75%)
# updating: games/LPL_A_342490_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2990684_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2794747_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3416228_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3212683_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2577202_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2684919_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3150637_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3179121_shortened.json (deflated 75%)
# updating: games/LPL_A_343381_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT03_2797096_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2883847_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2660083_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3338531_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2350353_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2561424_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2911660_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3211002_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3168430_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3155407_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3340970_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2541342_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3313367_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2708036_shortened.json (deflated 75%)
# updating: games/LPL_B_329133_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT04_2664759_shortened.json (deflated 75%)
# updating: games/LPL_B_328798_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2290325_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2541504_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2688474_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3371264_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3086223_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2773378_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2541898_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3394412_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2672222_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2545224_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT05_3241516_shortened.json (deflated 75%)
# updating: games/LPL_A_330592_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2816794_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2451191_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3223291_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3190075_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3161725_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3042187_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2664678_shortened.json (deflated 75%)
# updating: games/LPL_A_331483_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3177024_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3314339_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3393440_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3117507_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3406823_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3414842_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2964848_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2744630_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3131763_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2410385_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2830660_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2818738_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2689608_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2520616_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3415616_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2773891_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3042943_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3161608_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3143464_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3122736_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2657112_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3301748_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2530452_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2567121_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2942311_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3097984_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3319064_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3218146_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3385142_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2410268_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2895385_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2631291_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3060445_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2431634_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3308372_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2090543_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3098875_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3100398_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3043753_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2773972_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3123546_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3098400_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3127821_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2820108_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2655411_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2190889_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2971222_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2883013_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2775754_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2789672_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3060364_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2568649_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2451155_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3190912_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2770433_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2675883_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2776487_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3391622_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2971778_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2703543_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3309506_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2883883_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2780234_shortened.json (deflated 75%)
# updating: games/LPL_A_343741_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3216283_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3119640_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3190191_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3098956_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2745323_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2697747_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2712615_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3090406_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2905145_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3171805_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2451470_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2822205_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3217813_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2984964_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2543640_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2914531_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2580333_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2689725_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3330818_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2558131_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2702177_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3339224_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3160716_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2781996_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3222448_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3221239_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2733344_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2880976_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3225670_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2563798_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3216922_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2730833_shortened.json (deflated 75%)
# updating: games/LPL_A_334273_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3155605_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3333167_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2575060_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2110577_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3178669_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3191802_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2789671_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3085532_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3086261_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3100400_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2817883_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3217570_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2774386_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2210288_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3127506_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2558212_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2520814_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3166216_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3195598_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2980766_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3170671_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2571901_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2903282_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3411656_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3128073_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2731643_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2664797_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2651370_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3412709_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3090325_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2820184_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2411474_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2931144_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2906063_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3153139_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3338522_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2670430_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3218251_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT03_3126561_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2705039_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2740661_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2669277_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3314645_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3212674_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3371651_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3195868_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3096888_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3232276_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2686368_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2694867_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3151357_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2654869_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2940959_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2705912_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3060319_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2786395_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2840218_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2270075_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3221584_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2671720_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2785982_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2840137_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3130386_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2920641_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3218812_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2470530_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2551615_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2140088_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3213484_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2561019_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3313673_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2904362_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2798932_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3331817_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2786873_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3126804_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2689833_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3115239_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3198298_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3222394_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3217921_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2822313_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3342185_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3083460_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3128028_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2520607_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2950994_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3317552_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3124464_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2769382_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3174180_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3393431_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2569567_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2450615_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2745350_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3098983_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3177015_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3406814_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2689275_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2704544_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3301856_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2775781_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3083705_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3133374_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3184143_shortened.json (deflated 75%)
# updating: games/LPL_A_343930_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3158304_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3093506_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3408434_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2691080_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3169150_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2767681_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2690351_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3220459_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3160582_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3216715_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3175314_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2552740_shortened.json (deflated 75%)
# updating: games/LPL_B_328789_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2781789_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2810095_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2190441_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2797564_shortened.json (deflated 75%)
# updating: games/LPL_A_342409_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2290316_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2913830_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3087499_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3210496_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2750224_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3394797_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3129711_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3000403_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3217606_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3325814_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3294611_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2786558_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2782597_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3300884_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3241507_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3154507_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2420058_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3198021_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2240159_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2960521_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2941886_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2697020_shortened.json (deflated 75%)
# updating: games/LPL_A_335713_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT02_2553352_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3097500_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2930083_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2789825_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2774854_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2768293_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3372029_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2543154_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3217327_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3414473_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3326264_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3300211_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3324806_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3300767_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3313790_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3220891_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3099838_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2532306_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2686566_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3331934_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2430815_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3092334_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2553190_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3178975_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2820652_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2572063_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3126048_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2210835_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2210200_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2420139_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2520328_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3182244_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3143455_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2540244_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2705156_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2683974_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3221863_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3125238_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3117219_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2330069_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2771072_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3321890_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3140782_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3318164_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3376223_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2912506_shortened.json (deflated 75%)
# updating: games/LPL_A_335632_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2818288_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2772996_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3188302_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2819100_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3313637_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2664788_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3184341_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2555530_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3240571_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2706524_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2665758_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3166521_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3308840_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3170662_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2818765_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2980757_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3324167_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2665040_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2520643_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2689635_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3126606_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3122880_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3180228_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3330566_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2544441_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3408470_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3057505_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3220096_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2980201_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3090237_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3096688_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3220101_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2701277_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2789581_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3127092_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3410675_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2706605_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3181911_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3123852_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2810455_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3330809_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2672411_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2620834_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2840731_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3303755_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3207841_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3222670_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3086333_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2656211_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3240490_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3092570_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2568793_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3414077_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2472170_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3221926_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3060337_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2792974_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2734280_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3141736_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT04_2674965_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2270093_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3168124_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2788195_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2471603_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3216256_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3083165_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2520940_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3223066_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2780207_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3151375_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3374504_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2914027_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3302369_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3380741_shortened.json (deflated 75%)
# updating: games/LPL_A_334642_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT03_3092154_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2543136_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2530741_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3326246_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3340826_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3314582_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2895358_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2210574_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2170382_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT02_3144328_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3171931_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2631264_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3096987_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2692310_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3401189_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3412754_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3156460_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3131457_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_3227902_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2655697_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3222094_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2569981_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2823222_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2090354_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2667200_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3101496_shortened.json (deflated 76%)
# updating: games/ESPORTSTMNT01_3317732_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_3085422_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3339116_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2672150_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2973767_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3093524_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2693199_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2451524_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_3386321_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2557132_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2768671_shortened.json (deflated 75%)
# ...
# updating: games/ESPORTSTMNT01_2144995_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1885516_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1680365_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2570474_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2060688_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2565446_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2132307_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1961428_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2132460_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2093873_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1725963_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1810311_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1883338_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1991066_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2656805_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1830548_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1815395_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1880264_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1822685_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1481197_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1840349_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2075577_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1882285_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2135133_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1860348_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1970571_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2290547_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2138992_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2702995_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1581149_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2030256_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2148793_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2143789_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1721769_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2530793_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2547149_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1410116_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1970733_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1571186_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1767506_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1730837_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2071700_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1510222_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2030418_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1880345_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2651558_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1293792_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1600017_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1762934_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1822010_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1882249_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1580852_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1140423_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1962356_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1970616_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1934097_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2810133_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1885471_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3060588_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1334877_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1810588_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2913784_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1800787_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1830980_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2138794_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1971426_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1696425_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2060330_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2075298_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2733012_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1960494_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1881515_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1880462_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1981380_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2142621_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2884281_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2020019_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1325250_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2055220_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1750874_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1413700_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1881353_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2075937_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1670287_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2144241_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2093990_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1895911_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2090768_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1970376_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2572378_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1860068_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1640330_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_3090549_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2663574_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2060889_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1766813_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2060231_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1821495_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1800132_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1300941_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1690427_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1720577_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1934079_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1384656_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2930855_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2591629_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1333331_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2148658_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1394295_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1840844_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1690828_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2051404_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2073893_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2549507_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1881259_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1580591_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2006611_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2001607_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1821659_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1303533_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1331071_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1831377_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1764293_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_2431203_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1580753_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1690585_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2000392_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1394376_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1962257_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2051879_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1885372_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2793542_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1891933_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1520598_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1334221_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1750856_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1881335_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2131911_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1960638_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2250252_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2635457_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1960555_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1697451_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1961284_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1895812_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2240613_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2915863_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2706102_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1816628_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1760495_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_2470466_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2895431_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2055040_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1323134_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2140343_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1755941_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1830647_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2136679_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1433759_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2002570_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1992056_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1880284_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1697370_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1860923_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1960519_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1286682_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1306323_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1413008_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1481179_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1383963_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1690463_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1891177_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1342042_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2573286_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1996214_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1550200_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1820964_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2915827_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1925529_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1392719_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1881056_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1880327_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1810768_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2862448_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2102164_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1660189_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2884308_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2885351_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1887514_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1696281_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1756472_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2073696_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2093936_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1334895_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_1981083_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2941905_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1324303_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1392557_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1570754_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1991444_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1938075_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT05_2020037_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1995008_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2546555_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2137687_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2130424_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2655419_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1426113_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2136240_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1680347_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2906278_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1881934_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2065992_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1690549_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1324698_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_2151314_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT06_1860086_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1405142_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2546636_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1660585_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2003821_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1670386_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2142009_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1765940_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_2745088_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2007223_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_2102722_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1925682_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1324779_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1415502_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1890445_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT02_1396149_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT03_1757156_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT04_1970905_shortened.json (deflated 75%)
# updating: games/ESPORTSTMNT01_1896217_shortened.json

# %%
conda install -y -c conda-forge zip
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.9.0
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - zip
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     zip-3.0                    |       h7f98852_1         110 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   zip                conda-forge/linux-64::zip-3.0-h7f98852_1
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1v-h7f8727e_0 --> 1.1.1w-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1w       | 3.7 MB    |                                       |   0%
# openssl-1.1.1w       | 3.7 MB    | ################################6     |  88%
# zip-3.0              | 110 KB    | ##################################### | 100%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

def count_files_in_folder(folder_path):
    """
    Count the number of files in a folder.
    
    Parameters:
        folder_path (str): The path to the folder.
    
    Returns:
        int: The number of files in the folder.
    """
    try:
        # List all files and folders in the specified folder
        items = os.listdir(folder_path)
        
        # Count and return only the files (ignore subfolders)
        return sum(os.path.isfile(os.path.join(folder_path, item)) for item in items)
    except FileNotFoundError:
        print(f"The folder {folder_path} was not found.")
        return None
    except PermissionError:
        print(f"You do not have permission to access {folder_path}.")
        return None

# Example usage:
folder_path = 'games'
num_files = count_files_in_folder(folder_path)
print(f"There are {num_files} files in the folder {folder_path}.")

# %%
import os
import json

# Specify the directory containing the JSON files
directory = 'games'

# Initialize a list to store the combined data
combined_data = []

# Loop through all files in the specified directory
for filename in os.listdir(directory):
    # Check if the file is a JSON file
    if filename.endswith('.json'):
        # Construct the full file path
        filepath = os.path.join(directory, filename)

        # Open and load the JSON file
        with open(filepath, 'r') as file:
            data = json.load(file)

            # Append the data to the combined_data list
            combined_data.extend(data)

# Specify the name of the output file
output_file = 'combined_data.json'

# Write the combined data to the output file
with open(output_file, 'w') as file:
    json.dump(combined_data, file, indent=2)

print(f"Combined data written to {output_file}")
# Out:
# Combined data written to combined_data.json

# %%
import json

# Load JSON files
def load_json_file(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

teams_data = load_json_file('esports-data/teams.json')
players_data = load_json_file('esports-data/players.json')
mapping_data = load_json_file('esports-data/mapping_data.json')
combined_data = load_json_file('combined_data.json')
leagues_data = load_json_file('esports-data/leagues.json')
tournaments_data = load_json_file('esports-data/tournaments.json')

# Create mappings for easy lookup
team_id_to_name = {team['team_id']: team['name'] for team in teams_data}
player_id_to_handle = {player['player_id']: player['handle'] for player in players_data}
platform_game_id_to_combined_data = {game['platformGameId']: game for game in combined_data}
league_id_to_region = {league['id']: league['region'] for league in leagues_data}

# Define update functions
def update_team_info(node):
    if isinstance(node, dict):
        if 'team_id' in node and node['team_id'] in team_id_to_name:
            node['team_name'] = team_id_to_name[node['team_id']]
        for key in node:
            update_team_info(node[key])
    elif isinstance(node, list):
        for item in node:
            update_team_info(item)

def update_player_info(node):
    if isinstance(node, dict):
        if 'player_id' in node and node['player_id'] in player_id_to_handle:
            node['player_handle'] = player_id_to_handle[node['player_id']]
        for key in node:
            update_player_info(node[key])
    elif isinstance(node, list):
        for item in node:
            update_player_info(item)

def update_game_info(node):
    if isinstance(node, dict):
        if 'esportsGameId' in node and node['esportsGameId'] in platform_game_id_to_combined_data:
            node['platformGameId'] = platform_game_id_to_combined_data[node['esportsGameId']]['platformGameId']
            node['teamMapping'] = mapping_data[node['esportsGameId']]['teamMapping']
        for key in node:
            update_game_info(node[key])
    elif isinstance(node, list):
        for item in node:
            update_game_info(item)

def update_game_additional_info(node):
    if isinstance(node, dict):
        if 'platformGameId' in node and node['platformGameId'] in platform_game_id_to_combined_data:
            node['eventTime'] = platform_game_id_to_combined_data[node['platformGameId']]['eventTime']
            for team in node.get('teams', []):
                team_id = node['teamMapping'].get(str(team['teamID']))
                if team_id:
                    team['totalGold'] = next((t['totalGold'] for t in platform_game_id_to_combined_data[node['platformGameId']]['teams'] if t['teamID'] == int(team_id)), None)
        for key in node:
            update_game_additional_info(node[key])
    elif isinstance(node, list):
        for item in node:
            update_game_additional_info(item)

def update_region_info(node, current_region=None):
    if isinstance(node, dict):
        if 'leagueId' in node and node['leagueId'] in league_id_to_region:
            current_region = league_id_to_region[node['leagueId']]
        if 'team_name' in node and current_region is not None:
            node['region'] = current_region
        for key in node:
            update_region_info(node[key], current_region)
    elif isinstance(node, list):
        for item in node:
            update_region_info(item, current_region)

# Apply the transformations to each tournament in the tournaments_data list
for tournament in tournaments_data:
    update_team_info(tournament)
    update_player_info(tournament)
    update_game_info(tournament)
    update_game_additional_info(tournament)
    update_region_info(tournament)

# Get the current working directory
current_working_dir = os.getcwd()

# Define the path for the new JSON file in the current working directory
output_filepath = os.path.join(current_working_dir, 'updated_tournaments.json')

# Save the updated tournament data to the new JSON file
with open(output_filepath, 'w') as file:
    json.dump(tournaments_data, file, indent=4)

# %%
import json

# Load the datasets
with open('merged_mapping_data.json', 'r') as file:
    esport_data = json.load(file)

with open('esports-data/tournaments.json', 'r') as file:
    tournaments_data = json.load(file)

# Function to perform a deep search in a nested dictionary
def deep_search(key, value, data, path=[]):
    if isinstance(data, dict):
        for k, v in data.items():
            new_path = path + [k]
            for result in deep_search(key, value, v, new_path):
                yield result
    elif isinstance(data, list):
        for i, v in enumerate(data):
            new_path = path + [i]
            for result in deep_search(key, value, v, new_path):
                yield result

# Function to find tournament details based on esportsGameId
def find_tournament_details(game_id, tournaments_data):
    search_results = list(deep_search('id', game_id, tournaments_data))
    if search_results:
        path = search_results[0]
        tournament_index = path[0]
        tournament = tournaments_data[tournament_index]
        details = {
            'tournamentId': tournament.get('id'),
            'leagueId': tournament.get('leagueId'),
            'leagueSlug': tournament.get('slug'),
        }
        return details

# Applying the function to each game in the esports data
for game in esport_data:
    esports_game_id = game.get('esportsGameId')
    tournament_details = find_tournament_details(esports_game_id, tournaments_data)
    if tournament_details:
        game.update(tournament_details)

# Saving the updated data to a new JSON file
with open('updated_esport_data.json', 'w') as file:
    json.dump(esport_data, file, indent=4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 40
#      38 for game in esport_data:
#      39     esports_game_id = game.get('esportsGameId')
# ---> 40     tournament_details = find_tournament_details(esports_game_id, tournaments_data)
#      41     if tournament_details:
#      42         game.update(tournament_details)
#
# Cell In[10], line 25, in find_tournament_details(game_id, tournaments_data)
#      24 def find_tournament_details(game_id, tournaments_data):
# ---> 25     search_results = list(deep_search('id', game_id, tournaments_data))
#      26     if search_results:
#      27         path = search_results[0]
#
# Cell In[10], line 20, in deep_search(key, value, data, path)
#      18 for i, v in enumerate(data):
#      19     new_path = path + [i]
# ---> 20     for result in deep_search(key, value, v, new_path):
#      21         yield result
#
# Cell In[10], line 15, in deep_search(key, value, data, path)
#      13     for k, v in data.items():
#      14         new_path = path + [k]
# ---> 15         for result in deep_search(key, value, v, new_path):
#      16             yield result
#      17 elif isinstance(data, list):
#
# Cell In[10], line 20, in deep_search(key, value, data, path)
#      18 for i, v in enumerate(data):
#      19     new_path = path + [i]
# ---> 20     for result in deep_search(key, value, v, new_path):
#      21         yield result
#
# Cell In[10], line 15, in deep_search(key, value, data, path)
#      13     for k, v in data.items():
#      14         new_path = path + [k]
# ---> 15         for result in deep_search(key, value, v, new_path):
#      16             yield result
#      17 elif isinstance(data, list):
#
#     [... skipping similar frames: deep_search at line 20 (2 times), deep_search at line 15 (2 times)]
#
# Cell In[10], line 20, in deep_search(key, value, data, path)
#      18 for i, v in enumerate(data):
#      19     new_path = path + [i]
# ---> 20     for result in deep_search(key, value, v, new_path):
#      21         yield result
#
#     [... skipping similar frames: deep_search at line 15 (1 times)]
#
# Cell In[10], line 15, in deep_search(key, value, data, path)
#      13     for k, v in data.items():
#      14         new_path = path + [k]
# ---> 15         for result in deep_search(key, value, v, new_path):
#      16             yield result
#      17 elif isinstance(data, list):
#
# KeyboardInterrupt:

# %%
import json

# Load the tournaments data
with open('esports-data/tournaments.json') as file:
    tournaments_data = json.load(file)

# Load the merged_mapping_data
with open('merged_mapping_data.json') as file:
    esport_data = json.load(file)

# Function to perform a flexible search for the game ID within the tournaments data
def flexible_search(game_id_to_find, data, path=[]):
    if isinstance(data, dict):
        for key, value in data.items():
            new_path = path + [key]
            for result in flexible_search(game_id_to_find, value, new_path):
                yield result
    elif isinstance(data, list):
        for index, value in enumerate(data):
            new_path = path + [index]
            for result in flexible_search(game_id_to_find, value, new_path):
                yield result
    elif isinstance(data, (str, int)) and str(data) == str(game_id_to_find):
        yield path

# Function to trace back and retrieve tournament details based on the found path
def retrieve_tournament_details(path, tournaments_data):
    tournament_index = path[0]
    tournament = tournaments_data[tournament_index]
    return {
        'tournamentId': tournament.get('id'),
        'leagueId': tournament.get('leagueId'),
        'leagueSlug': tournament.get('slug')
    }

# Applying the flexible search and trace-back approach to all game IDs in the merged_mapping_data.json
for game in esport_data:
    esports_game_id = game.get('esportsGameId')
    search_results = list(flexible_search(esports_game_id, tournaments_data))
    if search_results:  # If any matching paths are found
        tournament_details = retrieve_tournament_details(search_results[0], tournaments_data)
        game.update(tournament_details)

# Saving the updated esports data to a new JSON file
with open('esport_data.json', 'w', encoding='utf-8') as file:
    json.dump(esport_data, file, ensure_ascii=False, indent=4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 39
#      37 for game in esport_data:
#      38     esports_game_id = game.get('esportsGameId')
# ---> 39     search_results = list(flexible_search(esports_game_id, tournaments_data))
#      40     if search_results:  # If any matching paths are found
#      41         tournament_details = retrieve_tournament_details(search_results[0], tournaments_data)
#
# Cell In[3], line 21, in flexible_search(game_id_to_find, data, path)
#      19     for index, value in enumerate(data):
#      20         new_path = path + [index]
# ---> 21         for result in flexible_search(game_id_to_find, value, new_path):
#      22             yield result
#      23 elif isinstance(data, (str, int)) and str(data) == str(game_id_to_find):
#
# Cell In[3], line 16, in flexible_search(game_id_to_find, data, path)
#      14     for key, value in data.items():
#      15         new_path = path + [key]
# ---> 16         for result in flexible_search(game_id_to_find, value, new_path):
#      17             yield result
#      18 elif isinstance(data, list):
#
# Cell In[3], line 21, in flexible_search(game_id_to_find, data, path)
#      19     for index, value in enumerate(data):
#      20         new_path = path + [index]
# ---> 21         for result in flexible_search(game_id_to_find, value, new_path):
#      22             yield result
#      23 elif isinstance(data, (str, int)) and str(data) == str(game_id_to_find):
#
# Cell In[3], line 16, in flexible_search(game_id_to_find, data, path)
#      14     for key, value in data.items():
#      15         new_path = path + [key]
# ---> 16         for result in flexible_search(game_id_to_find, value, new_path):
#      17             yield result
#      18 elif isinstance(data, list):
#
#     [... skipping similar frames: flexible_search at line 21 (3 times), flexible_search at line 16 (3 times)]
#
# Cell In[3], line 21, in flexible_search(game_id_to_find, data, path)
#      19     for index, value in enumerate(data):
#      20         new_path = path + [index]
# ---> 21         for result in flexible_search(game_id_to_find, value, new_path):
#      22             yield result
#      23 elif isinstance(data, (str, int)) and str(data) == str(game_id_to_find):
#
# Cell In[3], line 16, in flexible_search(game_id_to_find, data, path)
#      14     for key, value in data.items():
#      15         new_path = path + [key]
# ---> 16         for result in flexible_search(game_id_to_find, value, new_path):
#      17             yield result
#      18 elif isinstance(data, list):
#
# Cell In[3], line 23, in flexible_search(game_id_to_find, data, path)
#      21         for result in flexible_search(game_id_to_find, value, new_path):
#      22             yield result
# ---> 23 elif isinstance(data, (str, int)) and str(data) == str(game_id_to_find):
#      24     yield path
#
# KeyboardInterrupt:

# %%
import json

def is_team_mapping_complete(team_mapping):
    essential_fields = ['teamId', 'mappingId', 'totalGold', 'name', 'region']
    return all(field in team_mapping and team_mapping[field] for field in essential_fields)

def is_game_data_complete(game_data):
    essential_fields = ['esportsGameId', 'platformGameId', 'eventTime', 'tournamentId', 'leagueId', 'leagueSlug']
    if not all(field in game_data and game_data[field] for field in essential_fields):
        return False
    
    team_mappings = game_data.get('teamMappings', [])
    return all(is_team_mapping_complete(team_mapping) for team_mapping in team_mappings)

def preprocess_game_data(game_data):
    team_mappings = game_data['teamMappings']
    if len(team_mappings) < 2:
        return None
    
    team1, team2 = team_mappings
    gold_diff = abs(team1['totalGold'] - team2['totalGold'])
    
    if team1['totalGold'] > team2['totalGold']:
        winning_team = team1['name']
    elif team1['totalGold'] < team2['totalGold']:
        winning_team = team2['name']
    else:
        winning_team = 'Tie'
    
    game_data['goldDifference'] = gold_diff
    game_data['winningTeam'] = winning_team
    
    return game_data

# Load the data from the JSON file
input_file_path = 'path_to_your_input_file.json'
with open(input_file_path, 'r') as file:
    esports_data = json.load(file)

# Clean and preprocess the data
cleaned_esports_data = [game_data for game_data in esports_data if is_game_data_complete(game_data)]
preprocessed_esports_data = [preprocess_game_data(game_data.copy()) for game_data in cleaned_esports_data]
preprocessed_esports_data = [game_data for game_data in preprocessed_esports_data if game_data]

# Save the preprocessed data to a new JSON file
output_file_path = 'path_to_your_output_file.json'
with open(output_file_path, 'w', encoding='utf-8') as file:
    json.dump(preprocessed_esports_data, file, ensure_ascii=False, indent=4)
